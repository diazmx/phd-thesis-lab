# %%
import igraph as ig
import pandas as pd
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### Función para calcular las métricas de un grafo

def calcular_metricas(grafo, bip_num_nodes, simple_num_edges):
    num_nodes = abs(grafo.vcount() - bip_num_nodes)
    num_edges = abs(grafo.ecount() - simple_num_edges)
    densidad = grafo.density()
    modularidad = grafo.community_multilevel().modularity
    grado_promedio = sum(grafo.degree()) / grafo.vcount() if grafo.vcount() > 0 else 0
    
    # Si el grafo contiene una o más 
    if grafo.is_connected():
        distancia_promedio = grafo.average_path_length()
    else:
        # Encontrar el componente más grande
        componentes = grafo.decompose()
        if(len(componentes)) < 1:
            distancia_promedio = 0
        else:
            componente_mas_grande = max(componentes, key=lambda c: c.vcount())
            distancia_promedio = componente_mas_grande.average_path_length()
    
    num_componentes = len(grafo.components())
    coeficiente_clustering = grafo.transitivity_undirected()
    
    return {
        "n nodes": num_nodes,
        "n edges": num_edges,
        "Densidad": densidad,
        "Modularidad": modularidad,
        "Grado Promedio": grado_promedio,
        "Distancia Promedio": distancia_promedio,
        "Número de Componentes": num_componentes,
        "Coeficiente de Clustering": coeficiente_clustering
    }

def simple_projection(bigraph, typen=True):
    if typen:
        return bigraph.bipartite_projection(which=typen)
    else:
        return bigraph.bipartite_projection(which=typen)
    
# Función para asignar el identificador
def asignar_identificador(texto):
    if 'simple' in texto:
        if "disparity" in texto:
            return 1
        elif "noise" in texto:
            return 2
    elif 'weights' in texto:
        if "disparity" in texto:
            return 3
        elif "noise" in texto:
            return 4
    elif 'vector' in texto:
        if "disparity" in texto:
            return 5
        elif "noise" in texto:
            return 6
    elif 'master' in texto:
        if "disparity" in texto:
            return 7
        elif "noise" in texto:
            return 8
    elif 'hyperbolic' in texto:
        if "disparity" in texto:
            return 9
        elif "noise" in texto:
            return 10
    elif 'resall' in texto:
        if "disparity" in texto:
            return 11
        elif "noise" in texto:
            return 12
    else:
        return None  # O algún otro valor por defecto si no se encuentra ninguna de las subcadenas

# %%
##### **** hVariables selection **** #####
DATASET = "AMZ"
DATASET_PATH = "01-AMZ"
TOP_TYPE = True

if TOP_TYPE:
    DIRPATH = "../00-Data/"+DATASET_PATH+"/02-Graphs/01-Top/"
else:
    DIRPATH = "../00-Data/"+DATASET_PATH+"/02-Graphs/02-Bot/"

#bip_graph = ig.read("../00-Data/"+DATASET_PATH+"/02-Graphs/binet-"+DATASET+"-Rw.graphml")
bip_graph = ig.read("../00-Data/"+DATASET_PATH+"/02-Graphs/binet-"+DATASET+"-Rw.graphml")
bip_num_nodes = len(bip_graph.vs.select(type_eq=TOP_TYPE))
proj = simple_projection(bip_graph, TOP_TYPE)
edge_num_simple = proj.ecount()

# Ruta de la carpeta que contiene los archivos .graphml
archivos = glob.glob(os.path.join(DIRPATH, "*.graphml"))

# Lista para almacenar las métricas de cada grafo
metricas = []

# Procesar cada archivo .graphml
for archivo in archivos:
    g = ig.Graph.Read_GraphML(archivo)
    nombre_grafo = os.path.basename(archivo)
    metrica = calcular_metricas(g, bip_num_nodes, edge_num_simple)
    metrica["G"] = nombre_grafo
    metricas.append(metrica)

# Crear un DataFrame con las métricas
df_metricas = pd.DataFrame(metricas)

# Mostrar estadísticas descriptivas
print(df_metricas.describe())
# Out:
#            n nodes       n edges      Densidad  Modularidad  Grado Promedio  \
# count    48.000000  4.800000e+01  4.800000e+01    48.000000       48.000000
# mean    156.166667  6.554083e+05  1.203456e-02     0.639378      111.859198
# std     394.921610  4.723956e+05  1.092886e-02     0.141036      101.609462
# min       1.000000  3.410000e+02  9.182319e-08     0.452492        0.000742
# 25%       1.000000  2.185872e+05  7.292368e-05     0.547477        0.677607
# 50%       1.000000  5.886465e+05  1.357661e-02     0.588094      126.208132
# 75%       5.000000  1.172176e+06  2.214032e-02     0.706982      205.816446
# max    1214.000000  1.175322e+06  2.719086e-02     0.929884      252.766269
#
#        Distancia Promedio  Número de Componentes  Coeficiente de Clustering
# count           48.000000              48.000000                  47.000000
# mean             3.556436            3199.000000                   0.415701
# std              1.609853            3475.896052                   0.227613
# min              1.000000             307.000000                   0.000000
# 25%              2.739445             307.000000                   0.223805
# 50%              2.847122             352.000000                   0.536367
# 75%              4.675767            7267.250000                   0.605176
# max              8.896640            8081.000000                   0.647587

# %%
df = df_metricas.copy()

df["DS"] = DATASET
df['PB'] = df['G'].apply(asignar_identificador)
df = df.rename(columns={"n nodes":"|V|", "Distancia Promedio": "L",
                                    "Densidad":"d", "Modularidad":"Q",
                                    "Grado Promedio":"K", "n edges":"|E|",
                                    "Número de Componentes":"N", 
                                    "Coeficiente de Clustering":"CC"})
df
# Out:
#      |V|      |E|             d         Q           K         L     N  \
# 0      1   149265  2.374454e-02  0.550450  220.729268  2.742281   307
# 1      1   321149  1.976689e-02  0.553464  183.753039  2.793962   307
# 2   1214  1175320  1.530386e-07  0.560000    0.001237  1.666667  8079
# 3      5  1172262  7.094338e-05  0.923872    0.659206  7.769531  7324
# 4      1    28149  2.654735e-02  0.505621  246.784124  2.730385   348
# 5      1   152336  2.367348e-02  0.554334  220.068624  2.742739   307
# 6      1   161801  2.345444e-02  0.538516  218.032484  2.744576   307
# 7      1   521440  1.513186e-02  0.595909  140.665806  2.888914   308
# 8      5  1172277  7.059596e-05  0.835848    0.655978  4.675767  7310
# 9      5  1171929  7.865612e-05  0.844463    0.730873  4.675767  7177
# 10     1   408191  1.775261e-02  0.580793  165.028289  2.826633   308
# 11     1   671224  1.166564e-02  0.616636  108.443799  3.011936   347
# 12     1   155990  2.358892e-02  0.557178  219.282564  2.743501   307
# 13  1214  1175321  1.224309e-07  0.625000    0.000990  1.333333  8080
# 14  1214  1175320  1.530386e-07  0.560000    0.001237  1.666667  8079
# 15  1214  1175322  9.182319e-08  0.666667    0.000742  1.000000  8081
# 16     1    28614  2.653658e-02  0.504707  246.684092  2.730398   348
# 17     5  1172088  7.497346e-05  0.913906    0.696653  6.839892  7244
# 18     5  1172128  7.404700e-05  0.840113    0.688045  4.675767  7252
# 12  0.617039           AMZ_top_simple_noise_alpha1.graphml  AMZ   2
# 13  0.000000      AMZ_top_weights_disparity_alpha1.graphml  AMZ   3
# 14  0.000000     AMZ_top_weights_disparity_alpha15.graphml  AMZ   3
# 15       NaN     AMZ_top_weights_disparity_alpha05.graphml  AMZ   3
# 16  0.628513       AMZ_top_vector_disparity_alpha1.graphml  AMZ   5
# 17  0.305978       AMZ_top_master_disparity_alpha2.graphml  AMZ   7
# 18  0.093929   AMZ_top_hyperbolic_disparity_alpha1.graphml  AMZ   9
# 19  0.572354       AMZ_top_hyperbolic_noise_alpha2.graphml  AMZ  10
# 20  0.554446      AMZ_top_hyperbolic_noise_alpha15.graphml  AMZ  10
# 21  0.543091      AMZ_top_hyperbolic_noise_alpha05.graphml  AMZ  10
# 22  0.184387      AMZ_top_simple_disparity_alpha05.graphml  AMZ   1
# 23  0.345118      AMZ_top_simple_disparity_alpha15.graphml  AMZ   1
# 24  0.060372       AMZ_top_resall_disparity_alpha1.graphml  AMZ  11
# 25  0.647587           AMZ_top_vector_noise_alpha2.graphml  AMZ   6
# 26  0.528140          AMZ_top_weights_noise_alpha1.graphml  AMZ   4
# 27  0.528397           AMZ_top_resall_noise_alpha1.graphml  AMZ  12
# 28  0.572322         AMZ_top_weights_noise_alpha15.graphml  AMZ   4
# 29  0.559968         AMZ_top_weights_noise_alpha05.graphml  AMZ   4
# 30  0.546215          AMZ_top_resall_noise_alpha15.graphml  AMZ  12
# 31  0.561162          AMZ_top_resall_noise_alpha05.graphml  AMZ  12
# 32  0.366850       AMZ_top_simple_disparity_alpha2.graphml  AMZ   1
# 33  0.322789      AMZ_top_master_disparity_alpha15.graphml  AMZ   7
# 34  0.368549      AMZ_top_master_disparity_alpha05.graphml  AMZ   7
# 35  0.628540      AMZ_top_vector_disparity_alpha15.graphml  AMZ   5
# 36  0.628504      AMZ_top_vector_disparity_alpha05.graphml  AMZ   5
# 37  0.594232          AMZ_top_weights_noise_alpha2.graphml  AMZ   4
# 38  0.062118       AMZ_top_resall_disparity_alpha2.graphml  AMZ  11
# 39  0.644344           AMZ_top_vector_noise_alpha1.graphml  AMZ   6
# 40  0.536367       AMZ_top_hyperbolic_noise_alpha1.graphml  AMZ  10
# 41  0.126149   AMZ_top_hyperbolic_disparity_alpha2.graphml  AMZ   9
# 42  0.263222       AMZ_top_simple_disparity_alpha1.graphml  AMZ   1
# 43  0.641869          AMZ_top_vector_noise_alpha05.graphml  AMZ   6
# 44  0.647237          AMZ_top_vector_noise_alpha15.graphml  AMZ   6
# 45  0.571581           AMZ_top_resall_noise_alpha2.graphml  AMZ  12
# 46  0.057890      AMZ_top_resall_disparity_alpha05.graphml  AMZ  11
# 47  0.061582      AMZ_top_resall_disparity_alpha15.graphml  AMZ  11

# %%
if TOP_TYPE:
    df.to_csv("DF-MET-"+DATASET+"1.csv")
else:
    df.to_csv("DF-MET-"+DATASET+"2.csv")
