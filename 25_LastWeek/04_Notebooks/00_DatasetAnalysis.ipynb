# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## AMZ

# %%
filename = '00_Data/AMZ/AMZ.csv'

df = pd.read_csv(filename)
df = df.drop_duplicates()

# Copy to another df and convert all values to str.
df_copy = df.astype(str)

df_copy.to_csv('00_Data/AMZ/amz_train.csv', index=False)

# %%
num_bins = 50
n, bins, _ = plt.hist(df['uname'], num_bins, density=True, color='green', alpha=0.7)
plt.show()

# %% [markdown]
# ## HC

# %%
filename = "/Users/ddiaz/Documents/code/phd-thesis-lab/12-third_year/00-Data/02-HC/01-DistributionsCSV/HC-Rw.csv"

df = pd.read_csv(filename)
df = df.drop_duplicates()

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34317 entries, 0 to 148342
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    34317 non-null  int64
#  1   uname         34317 non-null  int64
#  2   role          27065 non-null  object
#  3   uward         4754 non-null   object
#  4   specialty     25774 non-null  object
#  5   team          20057 non-null  object
#  6   agentfor      3789 non-null   float64
#  7   type          34317 non-null  object
#  8   author        34317 non-null  int64
#  9   patient       34317 non-null  int64
#  10  topic         34317 non-null  object
#  11  treatingteam  34317 non-null  object
#  12  oward         34317 non-null  object
#  13  rname         34317 non-null  int64
#  14  ACTION        34317 non-null  int64
# dtypes: float64(1), int64(6), object(8)
# memory usage: 4.2+ MB
# None
# ...

# %%
# Number of resources
print(len(df[['position', 'specialties', 'teams', 'uward', 'agentfor']].drop_duplicates()))
# Out:
# 31

# %%
len(df['rname'].unique())
# Out:
# 4960

# %%
num_bins = 50
n, bins, _ = plt.hist(df['rname'], num_bins, density=True, color='green', alpha=0.7)
plt.show()

# %%
counts_df = df['rname'].value_counts().reset_index()

# Step 2: Sort values explicitly (value_counts handles descending by default)
counts_df = counts_df.sort_values(by='count', ascending=False)

# Step 3: Plot directly from Pandas using a bar configuration
counts_df.plot(x='rname', y='count', kind='bar', legend=False, color='coral')
# Out:
# <AxesSubplot: xlabel='rname'>
