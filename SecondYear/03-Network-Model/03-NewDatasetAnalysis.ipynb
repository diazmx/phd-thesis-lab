# %%
import numpy as np
import pandas as pd

# %%
filename = "kaggle.csv"

df = pd.read_csv(filename)
df = df[df.columns[1:]]

df
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     29926   15560         117961         119063         119195
# 1           1       917     333         118212         118225         118403
# 2           1     20279    5897         117961         118225         119223
# 3           1     38972  111670         117961         118026         123472
# 4           1     42093   15381         117961         118225         117878
# ...       ...       ...     ...            ...            ...            ...
# 49995       1     73144   70142         120140         117936         118360
# 49996       1     23096    7320         118349         117954         122672
# 49997       1     20292    4638         117961         118413         118352
# 49998       1     19998   52687         117961         118225         118352
# 49999       1      4675   94701         117961         118413         118783
#
# ...

# %%
df.drop_duplicates()
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     29926   15560         117961         119063         119195
# 1           1       917     333         118212         118225         118403
# 2           1     20279    5897         117961         118225         119223
# 3           1     38972  111670         117961         118026         123472
# 4           1     42093   15381         117961         118225         117878
# ...       ...       ...     ...            ...            ...            ...
# 49995       1     73144   70142         120140         117936         118360
# 49996       1     23096    7320         118349         117954         122672
# 49997       1     20292    4638         117961         118413         118352
# 49998       1     19998   52687         117961         118225         118352
# 49999       1      4675   94701         117961         118413         118783
#
# ...

# %%
df = df[df.columns[1:]]
df
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0         29926   15560         117961         119063         119195
# 1           917     333         118212         118225         118403
# 2         20279    5897         117961         118225         119223
# 3         38972  111670         117961         118026         123472
# 4         42093   15381         117961         118225         117878
# ...         ...     ...            ...            ...            ...
# 49995     73144   70142         120140         117936         118360
# 49996     23096    7320         118349         117954         122672
# 49997     20292    4638         117961         118413         118352
# 49998     19998   52687         117961         118225         118352
# 49999      4675   94701         117961         118413         118783
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          117905            129282       118424     118763
# ...

# %%
df.drop_duplicates()
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0         29926   15560         117961         119063         119195
# 1           917     333         118212         118225         118403
# 2         20279    5897         117961         118225         119223
# 3         38972  111670         117961         118026         123472
# 4         42093   15381         117961         118225         117878
# ...         ...     ...            ...            ...            ...
# 49995     73144   70142         120140         117936         118360
# 49996     23096    7320         118349         117954         122672
# 49997     20292    4638         117961         118413         118352
# 49998     19998   52687         117961         118225         118352
# 49999      4675   94701         117961         118413         118783
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          117905            129282       118424     118763
# ...
