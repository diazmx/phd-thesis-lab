# %%
import pandas as pd

# %%
filename = "kaggle50.csv"

df = pd.read_csv(filename)
df = df[df.columns[1:]]

df
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     27356    5108         117961         118300         119181
# 1           1       971   20462         117961         118413         120370
# 2           1     28598    1208         117961         118139         147019
# 3           1     80169   90018         119170         117962         119968
# 4           1     78591    6997         117961         117969         117878
# ...       ...       ...     ...            ...            ...            ...
# 49995       1     35498   85475         117961         118300         125919
# 49996       1     38972   59259         117961         118225         123472
# 49997       1      4675   11925         117961         118327         118518
# 49998       1     37651   41801         117916         118343         117878
# 49999       1     75834   71258         117961         118300         117884
#
# ...

# %%
len(df.drop_duplicates())
# Out:
# 99141

# %%
len(df.drop_duplicates()) - len(df)
# Out:
# -859

# %%
df2 = df[df.columns[1:]]
df2
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0         45412    4588         117961         118300         119995
# 1         78591   21943         117961         117903         117878
# 2         42093    2434         118752         118300         118631
# 3         33233   91334         117961         118225         120535
# 4          4675    6751         117961         118225         118518
# ...         ...     ...            ...            ...            ...
# 99995     74310  106629         117961         118225         118403
# 99996     16200     880         118106         118052         118543
# 99997     27406   23200         118290         119171          19772
# 99998     13878   15484         117961         118343         117920
# 99999     35994   70643         117961         118327         122299
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          120313            142545       118638     118322
# ...

# %%
df2.drop_duplicates()
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0         45412    4588         117961         118300         119995
# 1         78591   21943         117961         117903         117878
# 2         42093    2434         118752         118300         118631
# 3         33233   91334         117961         118225         120535
# 4          4675    6751         117961         118225         118518
# ...         ...     ...            ...            ...            ...
# 99995     74310  106629         117961         118225         118403
# 99996     16200     880         118106         118052         118543
# 99997     27406   23200         118290         119171          19772
# 99998     13878   15484         117961         118343         117920
# 99999     35994   70643         117961         118327         122299
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          120313            142545       118638     118322
# ...

# %%
99084 - len(df.drop_duplicates())
# Out:
# -57

# %%
s_total = 0
for col in df.columns:
    s_total += len(df[col].unique())
    print(col)

s_total
# Out:
# ACTION
# RESOURCE
# MGR_ID
# ROLE_ROLLUP_1
# ROLE_ROLLUP_2
# ROLE_DEPTNAME
# ROLE_TITLE
# ROLE_FAMILY_DESC
# ROLE_FAMILY
# ROLE_CODE
# 11150

# %%
filename = "../../00-Data/train.csv"

a_test = pd.read_csv(filename)

# %%
a_test
# Out:
#        ACTION    RID  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1  39353   85475         117961         118300         123472
# 1           1  17183    1540         117961         118343         123125
# 2           1  36724   14457         118219         118220         117884
# 3           1  36135    5396         117961         118343         119993
# 4           1  42680    5905         117929         117930         119569
# ...       ...    ...     ...            ...            ...            ...
# 32764       1  23497   16971         117961         118300         119993
# 32765       1  25139  311198          91261         118026         122392
# 32766       1  34924   28805         117961         118327         120299
# 32767       1  80574   55643         118256         118257         117945
# 32768       1  14354   59575         117916         118150         117920
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# ...

# %%
len(df[df.ACTION == 0])# - len(df)
# Out:
# 3191

# %%
(len(a_test) - len(a_test[a_test.ACTION == 0])) / len(a_test)
# Out:
# 0.9421099209618847

# %%
(len(df) - len(df[df.ACTION == 0])) / len(df)
# Out:
# 0.96778

# %%
s_total = 0
for col in a_test.columns[2:]:
    s_total += len(df[col].unique())
    print(col)

s_total
# Out:
# MGR_ID
# ROLE_ROLLUP_1
# ROLE_ROLLUP_2
# ROLE_DEPTNAME
# ROLE_TITLE
# ROLE_FAMILY_DESC
# ROLE_FAMILY
# ROLE_CODE
# 7020
