# %% [markdown]
# # Network Model - Analysis

# %%
# Libraries
import numpy as np
import pandas as pd
import igraph as ig
import networkx as nx
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from auxiliar_funcs import *
import matplotlib.pyplot as plt
#import powerlaw as plaw
from collections import Counter
from math import log2, ceil

# %% [markdown]
# ### Load Data

# %%
# LOAD DATA
url_file = "../00-Data/train.csv"
df_data = pd.read_csv(url_file)
print("Data loaded!")
print(df_data.info())

# User attributes
user_attrs = df_data.columns[2:]

# Number of users
n_users = len(df_data[user_attrs].drop_duplicates())
n_rsrcs = len(df_data.RESOURCE.drop_duplicates())
print("|U|: ", n_users) # Unique users
print("|R|: ", n_rsrcs) # Unique resources

# Create an index for every users
user_dict = {}
for u_idx, u_attr in enumerate(df_data[user_attrs].drop_duplicates().values):
    idx = "999" + str(u_idx) + "999"
    user_dict[int(idx)] = list(u_attr)
print("|U| :", len(user_dict))

# Create a new column to add in a DF
list_usr_idx = []
key_list = list(user_dict.keys()) # list out keys and values separately
val_list = list(user_dict.values())
for log in df_data[user_attrs].values:
    key_idx = val_list.index(list(log))
    list_usr_idx.append(key_list[key_idx])
print("|L'| :", len(list_usr_idx), " = |L| :", len(df_data))
df_data["USERID"] = list_usr_idx

print()
df_pos_entries = df_data[df_data.ACTION==1]
df_neg_entries = df_data[df_data.ACTION==0]
print('Num positive entries:',len(df_pos_entries), 
    "{:.4}%".format((len(df_pos_entries)/len(df_data))*100))
print('Num negative entries:',len(df_neg_entries),
    "{:.4}%".format((len(df_neg_entries)/len(df_data))*100))

##### ***** Cross-Validation Configuration ***** #####
k = 10
test_size = 0.2
kfold = StratifiedShuffleSplit(n_splits=k, test_size=test_size, random_state=1)

data_partition = kfold.split(df_data, df_data.ACTION)
data_corpus = [] # Lista donde se almacenan los k fols

for train_data, test_data in data_partition:        
    X_train, X_test = df_data.iloc[train_data], df_data.iloc[test_data]
    data_corpus.append([X_train, X_test])

print("Done!")
# Out:
# Data loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32769 entries, 0 to 32768
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ACTION            32769 non-null  int64
#  1   RESOURCE          32769 non-null  int64
#  2   MGR_ID            32769 non-null  int64
#  3   ROLE_ROLLUP_1     32769 non-null  int64
#  4   ROLE_ROLLUP_2     32769 non-null  int64
#  5   ROLE_DEPTNAME     32769 non-null  int64
#  6   ROLE_TITLE        32769 non-null  int64
#  7   ROLE_FAMILY_DESC  32769 non-null  int64
#  8   ROLE_FAMILY       32769 non-null  int64
#  9   ROLE_CODE         32769 non-null  int64
# dtypes: int64(10)
# memory usage: 2.5 MB
# None
# |U|:  9561
# |R|:  7518
# |U| : 9561
# |L'| : 32769  = |L| : 32769
#
# Num positive entries: 30872 94.21%
# Num negative entries: 1897 5.789%
# Done!

# %% [markdown]
# ### Data Pre-processing

# %%
##### ***** Control Variables ***** #####
id_kfold = 1
task4 = True
#########################################

df_train_k, df_test_k = data_corpus[id_kfold][0], data_corpus[id_kfold][1]
print("# Train access request =", len(df_train_k), 
      " %: {:.2f}".format((len(df_train_k)/(len(df_train_k)+len(df_test_k)))*100))
print("# Test access request =", len(df_test_k),
      " %: {:.2f}".format((len(df_test_k)/(len(df_train_k)+len(df_test_k)))*100))
print("# Total =", len(df_train_k)+len(df_test_k))
print()

##### ***** Task 1: Null and uknwokn values ***** #####
print("TASK 1: Done!"); print() # NA


##### ***** TASK 2: convert continuous values to categorical values ***** #####
print("TASK 2: Done!"); print() # NA 

##### ***** TASK 3: Drop duplicates access requests ***** #####
print("TASK 3: Drop duplicates access requests")
df_train_k_pos = df_train_k[df_train_k.ACTION==1]   # Train Pos
df_train_k_neg = df_train_k[df_train_k.ACTION==0]   # Train Neg
df_test_k_pos = df_test_k[df_test_k.ACTION==1]      # Test Pos
df_test_k_neg = df_test_k[df_test_k.ACTION==0]      # Test Neg
df_train_k_pos = df_train_k_pos[df_train_k_pos.columns[1:]].drop_duplicates()
df_train_k_neg = df_train_k_neg[df_train_k_neg.columns[1:]].drop_duplicates()
df_test_k_pos = df_test_k_pos[df_test_k_pos.columns[1:]].drop_duplicates()
df_test_k_neg = df_test_k_neg[df_test_k_neg.columns[1:]].drop_duplicates()
print()

print("# Solicitudes Train (+):", len(df_train_k_pos), " %: {:.2f}".format(
      (len(df_train_k_pos)/len(df_train_k))*100))
print("# Solicitudes Train (-):", len(df_train_k_neg), " %: {:.2f}".format(
      (len(df_train_k_neg)/len(df_train_k))*100))
print("# Solicitudes Test (+):", len(df_test_k_pos), " %: {:.2f}".format(
      (len(df_test_k_pos)/len(df_test_k))*100))
print("# Solicitudes Test (-):", len(df_test_k_neg), " %: {:.2f}".format(
      (len(df_test_k_neg)/len(df_test_k))*100))
print("# Train Users (+): ", len(df_train_k_pos.USERID.drop_duplicates()))
print("# Train Resrc (+): ", len(df_train_k_pos.RESOURCE.drop_duplicates()))
print("# Train Users (-): ", len(df_train_k_neg.USERID.drop_duplicates()))
print("# Train Resrc (-): ", len(df_train_k_neg.RESOURCE.drop_duplicates()))
print("# Test Users (+): ", len(df_test_k_pos.USERID.drop_duplicates()))
print("# Test Resrc (+): ", len(df_test_k_pos.RESOURCE.drop_duplicates()))
print("# Test Users (-): ", len(df_test_k_neg.USERID.drop_duplicates()))
print("# Test Resrc (-): ", len(df_test_k_neg.RESOURCE.drop_duplicates())); print()

if task4:
    # Filter resources
      n1 = 0
      n2 = 149
      top_list = df_train_k_pos.RESOURCE.value_counts()[:len(df_train_k_pos.RESOURCE.drop_duplicates())].index.tolist()
      # Filter the interval between n1 and n2
      top_list = top_list[n1:n2+1]
      print('#Filtered resources:', len(top_list))
      boolean_series = df_train_k_pos.RESOURCE.isin(top_list)
      df_train_k_pos = df_train_k_pos[boolean_series]
      bolean_series = df_train_k_neg.RESOURCE.isin(top_list)
      df_train_k_neg = df_train_k_neg[bolean_series]
      print("Done!")
# Out:
# # Train access request = 26215  %: 80.00
# # Test access request = 6554  %: 20.00
# # Total = 32769
#
# TASK 1: Done!
#
# TASK 2: Done!
#
# TASK 3: Drop duplicates access requests
#
# # Solicitudes Train (+): 24697  %: 94.21
# # Solicitudes Train (-): 1518  %: 5.79
# # Solicitudes Test (+): 6175  %: 94.22
# # Solicitudes Test (-): 379  %: 5.78
# # Train Users (+):  8548
# # Train Resrc (+):  6430
# # Train Users (-):  819
# # Train Resrc (-):  977
# # Test Users (+):  4060
# # Test Resrc (+):  2767
# # Test Users (-):  295
# # Test Resrc (-):  284
#
# #Filtered resources: 150
# Done!

# %% [markdown]
# ### Network Modelling

# %%
def build_network_model(data, usr_id_name, res_id_name, file_path=None):
    """
    Builds the Access Requests Bipartite Network from Access log.

    Args:
        data (pandas dataframe): The Access Log.
        usr_id_name (str): The name of the ID users column in the Access Log
        res_id_name (str): The name of the ID resources column in the Access Log
    
    Returns:
        Graph (iGraph): The Access Requests Bipartite Network.

    Raises:
        TypeError: If a network is not Bipartite.
    """
    
    list_of_edges = []
    bi_network = nx.Graph() # NetworkX Graph object

    for usr_idx, rsr_idx in data[[usr_id_name, res_id_name]].values:
        list_of_edges.append((int(usr_idx), int(rsr_idx))) # Tuple of edges
    bi_network.add_edges_from(list_of_edges) # Build Network with edges

    # Change networkX object to iGraph object
    bi_network = ig.Graph.from_networkx(bi_network)
    bi_network.vs['name'] = bi_network.vs["_nx_name"] # Clean name column
    del bi_network.vs["_nx_name"] # Remove uncleaned name column

    print(bi_network.summary())
    print(bi_network.vs())

    if not bi_network.is_bipartite():
        raise TypeError("The ARBN is not bipartite")

    ### Add type of node (user or resource)
    list_of_resources_in_data = list(data[res_id_name])
    list_node_type = []
    for node in bi_network.vs():
        if node['name'] in list_of_resources_in_data:
            list_node_type.append(1) # A resource
        else:
            list_node_type.append(0) # An user
    bi_network.vs["typen"] = list_node_type
    ### End node type

    if not file_path == None: # Create a file
        ig.write(bi_network, file_path)

    print("ARBN builded!")
    print(bi_network.summary())
    print("|U-Nodes| =", len(bi_network.vs.select(typen=0)))
    print("|R-Nodes| =", len(bi_network.vs.select(typen=1)))

    return bi_network

# %%
bip_network = build_network_model(df_train_k_pos, 'USERID', 'RESOURCE')
# Out:
# IGRAPH UN-- 5586 9501 --
# + attr: name (v)
# <igraph.VertexSeq object at 0x7fd28fe69dd0>
# ARBN builded!
# IGRAPH UN-- 5586 9501 --
# + attr: name (v), typen (v)
# |U-Nodes| = 5436
# |R-Nodes| = 150

# %% [markdown]
# ### User network

# %%
def get_edge_weight(i_node, j_node):
    """
    Compute the weight of an edge between i and j nodes.

    Args:
        i_node (networkX node): i node.
        j_node (networkX node): j node.
    
    Returns:
        weight (float): The weight between nodes.

    Raises:
        TypeError: if there are not an intersection
    """
    neighs_i = set(i_node.neighbors())
    neighs_j = set(j_node.neighbors())

    insersection_neighbors = neighs_i.intersection(neighs_j)
    
    weight = (len(insersection_neighbors)*len(insersection_neighbors)) / (len(neighs_i)*len(neighs_j))

    return weight


def bipartite_projection(biparte_network, node_type=0):
    """
    Generate a monopartite network from bipartite network.

    Parameters:
        bipartite_network (igraph Graph): The bipartie network.
        node_type (int): The set of nodes of the monopartite network.

    Returns:
        Graph (iGraph): The monopartite (projected) network.

    Raises:
        Some
    """

    #Check if the bipartite network is a bipartite network:
    if not biparte_network.is_bipartite():
        raise TypeError("The ARBN is not bipartite")

    # networkX object (more easy to buil)
    g = nx.Graph()

    # All opposite node set
    opposite_nodes = biparte_network.vs.select(typen=1)

    # Check for every node the same type
    for X_node in opposite_nodes:
        # Select all neighbors of the X_node
        neighbordhood = X_node.neighbors()

        for Y_node_i in neighbordhood:
            for Y_node_j in neighbordhood:
                # Ceck if both nodes are the same
                if Y_node_i['name'] != Y_node_j['name']:
                    # If there is no an edge generate
                    if not g.has_edge(Y_node_i['name'], Y_node_j['name']):
                        weight_ = get_edge_weight(Y_node_i, Y_node_j)
                        #print("Peso: ", Y_node_i['name'], "-", Y_node_j['name'], " => ", weight_)
                        g.add_edge(Y_node_i["name"], Y_node_j["name"],
                                   weight=weight_)                                 

    # Convert from networkX graph to igraph graph
    g = ig.Graph.from_networkx(g)
    g.vs["name"] = g.vs["_nx_name"]
    del g.vs["_nx_name"]
    
    return g

# %%
user_network = bipartite_projection(bip_network, 0)
print(user_network.summary())
# ig.write(user_network, "graphs/amz_user_network.gml")
# Out:
# IGRAPH UNW- 5436 743311 --
# + attr: name (v), weight (e)

# %% [markdown]
# ### Network Analysis

# %%
density = user_network.density()
print("Density:", "{:.4f}".format(density))

avg_degree = sum(user_network.degree()) / user_network.vcount()
print("Avg. degree", "{:.4f}".format(avg_degree))

components = user_network.components()
print("Connected Components:", len(components))

cc = user_network.transitivity_avglocal_undirected()
print("Clustering Coefficient:", "{:.4f}".format(cc))

L = user_network.average_path_length()
print("Average Path Length :", "{:.4f}".format(L))
# Out:
# Density: 0.0503
# Avg. degree 273.4772
# Connected Components: 1
# Clustering Coefficient: 0.8424
# Average Path Length : 2.4426

# %%
def calculate_log_binning(degrees_list, n_bins):
    """
    Compute the log-binning y-values.
    """
    current_sum = 0
    previous_k = 0
    y_values_log_bin_list = []
    x_values = []

    for i in range(1, n_bins):
        x_values.append(previous_k)
        current_k = 2 ** (i)
        current_sum = current_sum + current_k
        temp_y_value = sum(degrees_list[previous_k:current_k])
        temp_y_value = temp_y_value / (current_k-previous_k)
        y_values_log_bin_list.append(temp_y_value)
        previous_k = current_k

        if current_sum > len(degrees_list):
            x_values.append(previous_k)
            temp_y_value = sum(degrees_list[previous_k:len(degrees_list)])
            temp_y_value = temp_y_value / (len(degrees_list)-previous_k)
            y_values_log_bin_list.append(temp_y_value)            
            break

    return x_values, y_values_log_bin_list

# %%
max_degree = max(user_network.degree())
print(max_degree)

# Crear una lista donde se almacena
degree_list = np.zeros(max_degree, dtype=int)

for node in user_network.vs():    
    degree_list[node.degree()-1] = (degree_list[node.degree()-1] + 1)

degree_list = degree_list / user_network.vcount()

plt.clf()
fig, axs = plt.subplots(2, 2, figsize=(20,20))

# LINEAR SCALE
axs[0, 0].set_title('Linear Scale')
axs[0, 0].plot(degree_list, color='#e60049')
axs[0, 0].set(ylabel='P(k)', xlabel='k')

# LINEAR BINNING
axs[0, 1].set_title('Linear Binning')
axs[0, 1].plot(range(max_degree), degree_list, color="#e60049", marker='*', ls='None')
axs[0, 1].loglog()
axs[0, 1].set(ylabel='P(k)', xlabel='k')

# LOG-BINNING
axs[1, 0].set_title('Log-Binning')
n_log_bin = ceil(log2(max(user_network.degree())))
x_values, y_values = calculate_log_binning(degree_list, n_log_bin)
axs[1, 0].plot(x_values, y_values, color='#e60049', marker="D", ls='None')
axs[1, 0].loglog()
axs[1, 0].set(ylabel='P(k)', xlabel='k')

# COMULATIVE
axs[1, 1].set_title("Cumulative Distribution")
degree_sequence = sorted([d for d in user_network.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
cs = np.cumsum(np.array(cnt)/user_network.vcount())
axs[1, 1].loglog(deg, cs, color='#e60049', marker="D", ls='None')
axs[1, 1].set(ylabel='P(k)', xlabel='k')

fig.suptitle("Degree distribution - Amazon - Frequent resources", fontsize=24)
fig.tight_layout()
plt.show()
# Out:
# 1668

# %% [markdown]
# ### Weighted distribution

# %%
arreglo_test = (np.array(user_network.es['weight'])*1000).astype(int)
max_peso = max(arreglo_test)
print(max_peso)

# Crear una lista donde se almacena
arreglo_test_ = np.zeros(max_peso, dtype=int)

for node in arreglo_test:
    arreglo_test_[node-1] = (arreglo_test_[node-1] + 1)

arreglo_test_ = arreglo_test_ / user_network.ecount()

plt.clf()
plt.figure(figsize=(10,10))
plt.plot(arreglo_test_, color="#e60049")
plt.title("Weight distribution - AMZ - All resources")
plt.xlabel("w")
plt.ylabel("P(w)")
#plt.loglog()
plt.show()
# Out:
# 1000

# %%
user_network_test = user_network.copy()
user_network_test.es.select(weight_lt=0.4).delete()

# %%
density = user_network_test.density()
print("Density:", density)

avg_degree = sum(user_network_test.degree()) / user_network_test.vcount()
print("Avg. degree", avg_degree)

components = user_network_test.components()
print("Connected Components:", len(components))

# %% [markdown]
# ### Calculete changes of densities

# %%
densitites_list = [user_network.density()] # Store all densities values
thresholds_list = np.linspace(0, 1, num=11)[1:-1] # nine values

for thrs in thresholds_list:
    current_user_net = user_network.copy() # Create a copy of user network
    
    # Remove edges less than current threshold
    current_user_net.es.select(weight_lt=thrs).delete()
    
    current_density = current_user_net.density() # Compute density
    
    # Store current density in the density list
    densitites_list.append(current_density)

# Show densities
print(densitites_list)
# Out:
# [0.022874443231497874, 0.009990839019907624, 0.005340227964554199, 0.003177833267323172, 0.0022572399424410318, 0.002229144219662889, 0.0008576589058590997, 0.0008370455176734518, 0.0008365427521079481, 0.0008364540287728594]

# %%
plt.clf()
plt.figure(figsize=(10,10))
plt.plot([0]+list(thresholds_list), densitites_list, color="#e60049", marker='*')
plt.title("Densities - AMZ - All resources")
plt.xlabel("w")
plt.xticks([0]+list(thresholds_list))
plt.ylabel("Density")
plt.yticks(densitites_list)
plt.grid(axis='y')
plt.plot(0.3, densitites_list[3], marker="D", markersize=15, fillstyle='none', color="#4421af")
#plt.loglog()
plt.show()

# %% [markdown]
# ### Components Analysis

# %%
# Shows the size counter of the components
dict_compoenents = dict(Counter(components.sizes()))
print(dict_compoenents)
# Out:
# {8068: 1, 2: 46, 3: 14, 4: 4, 6: 1}
# dict_values([1, 46, 14, 4, 1])

# %%
fig, ax = plt.subplots(figsize=(8,))
ax.pie(dict_compoenents.values(), labels=dict_compoenents.keys(), 
       autopct='%1.1f%%', startangle=90, shadow=True, pctdistance=.85)
plt.show()

# %%
### Compute the % of nodes in the huge component

# In this case, we have huge component in index=0
huge_component = components.subgraph(0)
print("HugeComp Nodes:", huge_component.vcount())
print("HugeComp Edges:", huge_component.ecount())

# We recall how many user there
n_users_bip = user_network.vcount()
print("|Nodes| =", n_users_bip)

# % of nodes in the huge component
pct_users_huge = huge_component.vcount() / n_users_bip
print("Pct of nodes: {:.2f}%".format(pct_users_huge*100))

# % of links in the huge component 
n_res_bip = user_network.ecount()
print("|Edges| =", n_res_bip)
pct_res_huge = huge_component.ecount() / n_res_bip
print("Pct of edges: {:.2f}%".format(pct_res_huge*100))
# Out:
# HugeComp Nodes: 8068
# HugeComp Edges: 773338
# |Nodes| = 8224
# Pct of nodes: 98.10%
# |Edges| = 773453
# Pct of edges: 99.99%

# %%
### Compute the resources in the components.

counter_res = [] # Save all resources 
counter_res_huge = [] # Save resources in huge component

for compnt in components.subgraphs(): # Omit the huge component
    # Get node users
    users_comp = list(compnt.vs())    
    
    rsrc_in_components = [] # Store "name" attribute of resources

    # Loop over user nodes
    for i_node in users_comp:
        # Search the node in the bipartite network by its name
        i_query = bip_network.vs.find(name=i_node["name"])

        # Get the resources (neighbors) of i_node
        neighs_inodes = bip_network.neighbors(i_query)
        
        # loop over the resources
        for i_rsrc in neighs_inodes:
            # Adding to list
            rsrc_in_components.append(bip_network.vs(i_rsrc)[0]["name"])

    # Remove duplicate values
    rsrc_in_components = list(set(rsrc_in_components))
    
    if len(users_comp) == 8068: # The huge component
        counter_res_huge += rsrc_in_components
    else:
        counter_res += rsrc_in_components # Global resources in small components

# Remove duplicate values
counter_res = list(set(counter_res))
print(len(counter_res), counter_res)

counter_res_huge = list(set(counter_res_huge))
print(len(counter_res_huge), counter_res_huge)
# Out:
# 117 [74241, 73741, 36885, 78882, 75815, 89134, 35374, 80947, 73783, 84024, 74297, 79936, 6723, 77390, 34895, 31834, 78429, 78435, 78436, 16997, 36971, 99949, 74874, 100475, 36476, 77946, 74367, 77951, 74369, 27786, 74896, 32401, 74899, 30868, 80021, 79000, 25753, 43165, 27309, 31921, 31922, 74930, 45236, 45237, 73907, 35000, 109753, 71866, 16570, 39612, 31936, 36036, 6855, 716, 79566, 74447, 28370, 42709, 19678, 6878, 74982, 78570, 37115, 27901, 43265, 20744, 39695, 75032, 79640, 78108, 34076, 78111, 40753, 25407, 27970, 26436, 15697, 43860, 56665, 33115, 78178, 37221, 37222, 43879, 26985, 30573, 74610, 73075, 28532, 36724, 74614, 78713, 35716, 28550, 35722, 43915, 45451, 42382, 42383, 37781, 28568, 36772, 75685, 23461, 77225, 44975, 41399, 42945, 70088, 42967, 41433, 32223, 35819, 45044, 74743, 34300, 105470]
 34964, 34966, 100508, 34974, 100511, 100514, 100515, 34982, 34983, 34984, 34985, 34986, 34989, 34990, 34991, 34993, 35002, 2235, 35004, 35012, 35014, 35015, 35016, 35017, 2252, 35021, 35027, 35040, 35041, 35042, 35043, 35044, 35046, 35050, 35051, 35055, 35066, 2298, 35068, 35067, 2341, 2342, 35133, 35134, 2375, 2377, 35151, 35152, 2408, 35185, 35186, 35190, 35196, 35197, 35200, 35201, 35208, 35209, 35210, 35237, 35239, 35248, 35261, 35265, 35267, 35270, 35278, 35290, 35296, 35298, 35303, 35326, 35332, 35343, 35345, 100886, 35356, 35376, 2609, 35381, 100929, 35394, 35398, 100935, 35401, 35407, 100946, 2642, 100948, 35417, 2651, 35423, 35424, 35429, 100968, 100970, 100973, 100976, 35444, 35451, 35455, 35466, 35469, 35493, 35494, 35498, 35499, 35502, 35508, 35511, 35524, 35525, 35526, 35528, 35529, 35531, 35532, 35533, 35540, 2788, 2789, 2790, 2801, 2809, 2824, 35625, 35626, 35627, 35632, 35634, 35636, 35643, 35645, 35648, 35649, 35652, 35655, 35659, 35683, 35684, 2925, 35708, 35 ...

# %%
### Number of resources in each component
# Total of resources
total_counter_res = counter_res + counter_res_huge

# Remove duplicate values
total_counter_res = list(set(total_counter_res))

# % of resources in small components of all
pct_res = (len(counter_res) / len(total_counter_res))*100
print("Pct of resources (SMALL): {:.2f}% - ({} / {})".format(pct_res,
                                                             len(counter_res),
                                                             len(total_counter_res)))

# % of resources in small components of all
pct_res = (len(counter_res_huge) / len(total_counter_res))*100
print("Pct of resources (HUGE): {:.2f}% - ({} / {})".format(pct_res, 
                                                            len(counter_res_huge),
                                                            len(total_counter_res)))
# Out:
# Pct of resources (SMALL): 1.93% - (117 / 6061)
# Pct of resources (HUGE): 98.07% - (5944 / 6061)

# %%
### Importance of resources in each component

dict_freq_res = {} # Save counter access

for i_res in counter_res: # Small components
    # Number of accesss requests in Dataframe
    dict_freq_res[i_res] = len(df_train_k_pos[df_train_k_pos.RESOURCE==i_res])

print("MAX access in a resource (SMALL):", max(dict_freq_res.values()))

for i_res in counter_res_huge: # Small components
    # Number of accesss requests in Dataframe
    dict_freq_res[i_res] = len(df_train_k_pos[df_train_k_pos.RESOURCE==i_res])

print("MAX access in a resource (HUGE):", max(dict_freq_res.values()))
# Out:
# MAX access in a resource (SMALL): 5
# MAX access in a resource (HUGE): 671

# %%
### Analysis all networks vs huge compoenent

density = user_network.density()
print("Density (ALL):", "{:.4f}".format(density))
density = huge_component.density()
print("Density (HUGE):", "{:.4f}".format(density))

avg_degree = sum(user_network.degree()) / user_network.vcount()
print("Avg. degree (ALL)", "{:.4f}".format(avg_degree))
avg_degree = sum(huge_component.degree()) / huge_component.vcount()
print("Avg. degree (HUGE)", "{:.4f}".format(avg_degree))

components = user_network.components()
print("Connected Components (ALL):", len(components))
components = huge_component.components()
print("Connected Components (HUGE):", len(components))

cc = user_network.transitivity_avglocal_undirected()
print("Clustering Coefficient (ALL):", "{:.4f}".format(cc))
cc = huge_component.transitivity_avglocal_undirected()
print("Clustering Coefficient: (HUGE)", "{:.4f}".format(cc))

L = user_network.average_path_length()
print("Average Path Length (ALL):", "{:.4f}".format(L))
L = huge_component.average_path_length()
print("Average Path Length (HUGE):", "{:.4f}".format(L))
# Out:
# Density (ALL): 0.0229
# Density (HUGE): 0.0238
# Avg. degree (ALL) 188.0965
# Avg. degree (HUGE) 191.7050
# Connected Components (ALL): 66
# Connected Components (HUGE): 1
# Clustering Coefficient (ALL): 0.7931
# Clustering Coefficient: (HUGE) 0.7924
# Average Path Length (ALL): 2.8750
# Average Path Length (HUGE): 2.8750

# %% [markdown]
# ### Community Analysis

# %%
### Community detection algorithm

# Louvain Algorithm
partition = user_network.community_multilevel(weights=user_network.es()["weight"])
print("Modularity: %.4f" % partition.modularity) # Modualarity value

# Add cluster attribute to nodes
user_network.vs["cluster"] = partition.membership

print(user_network.summary())
print(partition.summary())
# Out:
# Modularity: 0.6509
# IGRAPH UNW- 5436 743311 --
# + attr: cluster (v), name (v), weight (e)
# Clustering with 5436 elements and 16 clusters

# %%
def agregar_identificador_com(grafo, set_usuarios, id_):
    for user_ in set_usuarios:
        vertice = grafo.vs.find(name=user_)
        vertice["cluster"] = id_

# %%
# Se obtienen las comunidades y sub-comunidades
g = user_network

density_threshold = 0.5

n_coms = len(set(g.vs["cluster"]))
count_n_coms = 0 # Contador de número de comunidades detectadas
# Diccionario con las comunidades. Id de la comunidad como key y una lista 
# como value {01: [subgrafo, recursos_list]}
dict_total_coms = {} 
id_comunidad = 0

for idx_comm in range(n_coms): # Recorrer cada comunidad en la red
    subgraph_nodes = g.vs.select(cluster=idx_comm) # Sacamos los nodos con el cluster
    comm_subgraph = subgraph_nodes.subgraph() # Objeto de subgrafo

    # Verificar si la densidad es baja: Si es baja se puede clasificar
    if comm_subgraph.density() < density_threshold:

        # Se realiza nuevamente una partición
        new_partition = comm_subgraph.community_multilevel(
            weights =comm_subgraph.es["weight"] )        

        for sub_com in new_partition.subgraphs(): # Se recorre cada nueva sub comunidad
            # Usuarios en la comunidad
            user_set_comm = sub_com.vs()["name"]   
            # Recursos en la comunidad
            n_res = num_recursos(user_set_comm, bip_network)            
            dict_total_coms[str(count_n_coms)] = [sub_com, n_res]
            agregar_identificador_com(g, user_set_comm, id_comunidad)
            id_comunidad += 1
            count_n_coms += 1
    else:
        user_set_comm = comm_subgraph.vs()["name"]   
        # Recursos en la comunidad
        n_res = num_recursos(user_set_comm, bip_network)            
        dict_total_coms[str(count_n_coms)] = [comm_subgraph, n_res]
        agregar_identificador_com(g, user_set_comm, id_comunidad)
        id_comunidad += 1
        count_n_coms += 1

print("# de Comunidades: ", len(dict_total_coms))
# Out:
# # de Comunidades:  90

# %%
### Classify communities
def num_recursos(user_sets, grafo_bip):
    all_recursos = set()
    user_sets = [int(float(i)) for i in user_sets]
    for user in user_sets:
        user_node = grafo_bip.vs.find(name=int(float(user)))
        vecinos_recurso = user_node.neighbors()
        vecinos_recurso = [nodo["name"] for nodo in vecinos_recurso]
        vecinos_recurso = set(vecinos_recurso)    
        all_recursos = all_recursos.union(vecinos_recurso)
    return list(all_recursos)            

def numero_registros2(sub_com, dataf):
    """Retorna los registros en una comunidad."""
    dict_resc = {}
    for node in sub_com.vs():
        recursos = list(dataf[dataf.USRID == float(node["label"])]["RESID"])
        for i in recursos:
            if i in dict_resc.keys():
                dict_resc[i] += 1
            else:
                dict_resc[i] = 1
    
    # Remove low values
    dict_temp = {}
    for item in dict_resc.items():
        if item[1] > 2:
            dict_temp[item[0]] = item[1]
    dict_temp = dict(sorted(dict_temp.items(), key=lambda item: item[1], reverse=True))

    if len(dict_temp) < 1:
        return  len(list(dict_temp.keys()))
    return len(list(dict_temp.keys()))

def numero_registros3(sub_com, dataf):
    """Retorna los registros en una comunidad."""
    dict_resc = {}
    for node in sub_com.vs():
        recursos = list(dataf[dataf.USRID == float(node["label"])]["RESID"])
        for i in recursos:
            if i in dict_resc.keys():
                dict_resc[i] += 1
            else:
                dict_resc[i] = 1
    
    # Remove low values
    dict_temp = {}
    for item in dict_resc.items():
        if item[1] > 2:
            dict_temp[item[0]] = item[1]
    dict_temp = dict(sorted(dict_temp.items(), key=lambda item: item[1], reverse=True))

    if len(dict_temp) < 1:
        return  dict_temp
    # return len(list(dict_temp.keys()))
    return dict_temp


def numero_registros4(sub_com, dataf):
    """Retorna los registros en una comunidad."""
    dict_resc = {}
    for node in sub_com.vs():
        recursos = list(dataf[dataf.USRID == int(node["label"])]["RESID"])
        for i in recursos:
            if i in dict_resc.keys():
                dict_resc[i] += 1
            else:
                dict_resc[i] = 1
    
    # Remove low values
    dict_temp = {}
    for item in dict_resc.items():
        if item[1] > 2:
            dict_temp[item[0]] = item[1]
    dict_temp = dict(sorted(dict_temp.items(), key=lambda item: item[1], reverse=True))

    if len(dict_temp) < 1:
        return  dict_temp
    # return len(list(dict_temp.keys()))
    return dict_temp

def get_users_from_resource_comms(resource_id, community, data):
    """Retorna los usuarios de la comunidad que acceden al conjunto de recursos"""
    users_to_ret = []
    for res in resource_id:
        all_user_in_community = community.vs()["label"] # Extraer usuarios de comunidad
        ## all_user_in_community = [int(item) for item in all_user_in_community] # Convertimos a int
        all_user_in_community = set(all_user_in_community) # Covnertimos a conjunto
        solicitudes_en_data = data[data["RESID"]==res]["USRID"].to_list() # Todos los usuarios que acceden al recurso
        solicitudes_en_data = [str(item)+".0" for item in solicitudes_en_data]
        solicitudes_en_data = set(solicitudes_en_data)
        # print(all_user_in_community)
        # print(solicitudes_en_data)
        users_to_ret = users_to_ret + list(all_user_in_community.intersection(solicitudes_en_data)) # Intersección
    users_to_ret = list(set(users_to_ret))
    return users_to_ret

def remove_equal_rules(rules):
    """ Remove equal rules X -> Y == Y -> X"""
    to_remove = []
    lrules = len(rules)
    for i in range(lrules):
        for j in range(i+1,lrules):
            if rules[i][0] == rules[j][1] and rules[i][1] == rules[j][0]:        
                to_remove.append(rules[i])

    #print(to_remove)
    return to_remove

def remove_equal_rules2(rules):
    """ Remove equal rules X -> Y == Y -> X"""
    to_remove = []
    for rule in rules:
        descri = []
        for ele in rule[0]:
            descri.append(ele)
        for ele in rule[1]:
            descri.append(ele)
        descri.sort()
        if descri in to_remove:
            continue
        else:            
            to_remove.append(descri)

    # Quedarse con la de mayor tamaño
    max_id = 0
    to_ret = None
    for i in to_remove:        
        if len(i) > max_id:            
            max_id = len(i)
            to_ret = i

    return [to_ret]

# Function to check if a value appear in column
def get_attr_name(value, df_):
    """ Return name of the column of the value."""
    cols = df_.columns  
    if value == 10:
            # Buscar el atributo maximo
        max_val = 0
        attr_  = None
        for i in cols:        
            t = len(df_[df_[i]==10])            
            if t > max_val:
                max_val = t
                attr_ = i
        return attr_
    else:
        for i in range(len(cols)):        
            if len(df_[df_[cols[i]]==value]) > 0:
                return df_.columns[i]

def get_attr_val_in_users(users_id, data):
    """Retorna los atributo valor en comun en un conjunto de usuarios."""
    user_convert = [float(n) for n in users_id] # Convertimos a float
    attr_user_ = data[data["USRID"].isin(user_convert)].drop_duplicates() # Seleccionamos usuarios
    attr_user__ = attr_user_[user_attr+["USRID"]].values.tolist() # Seleccionamos attributos de los usuarios
    attr_user_ = attr_user_[user_attr+["USRID"]]
    # print(attr_user_)
    init_Sup = 0.6
    init_Conf = 0.9
    rules = []
    while len(rules) == 0:
        # print("Sup", init_Sup, "  Conf", init_Conf)
        _, rules = apriori(attr_user__, minSup=init_Sup, minConf=init_Conf) # Apply apriori
        init_Sup -= 0.1
        init_Conf -= 0.1
    # print(rules)
    rules = remove_equal_rules2(rules)
    #print("XXX",rules)
    #for r in rules:
    #    print(r)
    
    reglas_karimi = []
    for r in rules:      
        for t in r:                                    
            col = get_attr_name(t, attr_user_)                                                             
            reglas_karimi.append([col, t])

    return reglas_karimi

def get_attr_val_in_users_2(users_id, data):
    """Retorna los atributo valor en comun en un conjunto de usuarios."""
    user_convert = [float(n) for n in users_id] # Convertimos a float
    attr_user_ = data[data["USRID"].isin(user_convert)].drop_duplicates() # Seleccionamos usuarios
    attr_user__ = attr_user_[user_attr].values.tolist() # Seleccionamos attributos de los usuarios
    attr_user_ = attr_user_[user_attr+["USRID"]]
    # print(attr_user_)
    init_Sup = 0.6
    init_Conf = 0.9
    rules = []
    while len(rules) == 0:
        # print("Sup", init_Sup, "  Conf", init_Conf)
        _, rules = apriori(attr_user__, minSup=init_Sup, minConf=init_Conf) # Apply apriori
        init_Sup -= 0.1
        init_Conf -= 0.1
        if init_Sup < 0:
            return attr_user__
    # print(rules)
    rules = remove_equal_rules2(rules)
    #print("XXX",rules)
    #for r in rules:
    #    print(r)
    
    reglas_karimi = []
    for r in rules:      
        for t in r:                                    
            col = get_attr_name(t, attr_user_)                                                             
            reglas_karimi.append([col, t])

    return reglas_karimi

def get_attr_val_in_res(res_ids, data):
    """Retorna los atributo valor en comun en un conjunto de usuarios."""    
    user_convert = [float(n) for n in res_ids] # Convertimos a float
    attr_user_ = data[data["RESID"].isin(user_convert)].drop_duplicates() # Seleccionamos usuarios
    attr_user__ = attr_user_[rsrc_attr].values.tolist() # Seleccionamos attributos de los usuarios
    attr_user_ = attr_user_[rsrc_attr+["RESID"]]
    #print(attr_user_)
    # print(attr_user_)
    init_Sup = 0.6
    init_Conf = 0.9
    rules = []
    while len(rules) == 0:
        # print("Sup", init_Sup, "  Conf", init_Conf)
        _, rules = apriori(attr_user__, minSup=init_Sup, minConf=init_Conf) # Apply apriori
        init_Sup -= 0.1
        init_Conf -= 0.1
    # _, rules = apriori(attr_user__, minSup=0.6, minConf=0.9) # Apply apriori
    rules = remove_equal_rules2(rules)
    #for r in rules:
    #    print(r)
    
    reglas_karimi = []
    for r in rules:      
        for t in r:                                    
            col = get_attr_name(t, attr_user_)                                                             
            reglas_karimi.append([col, t])

    return reglas_karimi

def get_attr_val_in_res_2(res_ids, data):
    """Retorna los atributo valor en comun en un conjunto de usuarios."""    
    user_convert = [float(n) for n in res_ids] # Convertimos a float
    attr_user_ = data[data["RESID"].isin(user_convert)].drop_duplicates() # Seleccionamos usuarios
    attr_user__ = attr_user_[rsrc_attr].values.tolist() # Seleccionamos attributos de los usuarios
    attr_user_ = attr_user_[rsrc_attr+["RESID"]]
    #print(attr_user_)
    # print(attr_user_)
    init_Sup = 0.6
    init_Conf = 0.9
    rules = []
    while len(rules) == 0:
        # print("Sup", init_Sup, "  Conf", init_Conf)
        _, rules = apriori(attr_user__, minSup=init_Sup, minConf=init_Conf) # Apply apriori
        init_Sup -= 0.1
        init_Conf -= 0.1
        if init_Sup < 0:
            return attr_user__
    # _, rules = apriori(attr_user__, minSup=0.6, minConf=0.9) # Apply apriori
    rules = remove_equal_rules2(rules)
    #for r in rules:
    #    print(r)
    
    reglas_karimi = []
    for r in rules:      
        for t in r:                                    
            col = get_attr_name(t, attr_user_)                                                             
            reglas_karimi.append([col, t])

    return reglas_karimi


def podado_recursos(recursos, subgrafo, umbral):
    """Realiza el podado de los recursos que casi no acceden"""
    n_usuarios = subgrafo.vcount()
    to_ret = {}    
    for i in recursos:
        us_temp = recursos[i]
        if (us_temp / n_usuarios) > umbral:
            to_ret[i] = us_temp
    return to_ret

def recurso_significativo(recursos, subgrafo, umbral):
    """Retorna el recurso significativo. 'None' si no hay."""
    n_usuarios = subgrafo.vcount()
    to_ret = {}    
    for i in recursos:
        us_temp = recursos[i]
        if (us_temp / n_usuarios) >= umbral:
            return to_ret[i]
    return None

def extraer_recursos_similares(recursos, data_, umbral):
    """Retorna registros similares como nuevos registros"""

    for atr in rsrc_attr: # Se reccorre los atributos
        for r1 in recursos: # Se recorre los recursos
            for atr2 in rsrc_attr:
                if atr != atr2: # Se cambian los recursos
                    print()


def get_apriori_final(usuarios, recursos, data):
    """Retorna los atributo valor en comun en un conjunto de usuarios."""
    user_convert = [float(n) for n in usuarios] # Convertimos a float
    attr_user_ = data[data["USRID"].isin(user_convert)].drop_duplicates() # Seleccionamos usuarios
    res_convert = [float(n) for n in recursos] # Convertimos a float
    attr_user_ = attr_user_[attr_user_["RESID"].isin(res_convert)].drop_duplicates() # Seleccionamos recursos
    attr_user__ = attr_user_[user_attr+rsrc_attr].values.tolist() # Seleccionamos attributos de los usuarios
    attr_user_ = attr_user_[user_attr+rsrc_attr]
    # print(attr_user_)
    init_Sup = 0.5
    init_Conf = 0.8
    rules = []
    while len(rules) == 0:
        _, rules = apriori(attr_user__, minSup=init_Sup, minConf=init_Conf) # Apply apriori
        init_Sup -= 0.1
        init_Conf -= 0.1
    # print(rules)
    rules = remove_equal_rules2(rules)
    
    reglas_karimi = []
    for r in rules:      
        for t in r:                                    
            col = get_attr_name(t, attr_user_)                                                             
            reglas_karimi.append([col, t])

    return reglas_karimi

def agregar_diccionario(diccionario, recurso, tupla_datos):
    if recurso in diccionario:
        diccionario[recurso].append(tupla_datos)
    else:
        diccionario[recurso] = [tupla_datos]

def agregar_usuario_com(diccio, com_id, usuario):
    if com_id in diccio:
        if not usuario in diccio[com_id]:
            diccio[com_id].append(usuario)
    else:
        
        diccio[com_id] = [usuario]

# %%
# Obtener el máximo valor de recursos en el total de comunidades
n_res_in_comms = [len(i[1]) for i in dict_total_coms.values()]
max_n_res = max(n_res_in_comms)
print("Comunidad con # mayor recursos", max_n_res)

# Umbrales para la clasificación de comunidades
big_threshold = int(0.50 * max_n_res)
med_threshold = int(0.25 * max_n_res)
print("Big Threshold: ", big_threshold, " \t\t Med Threshold", med_threshold)
# Out:
# Comunidad con # mayor recursos 105
# Big Threshold:  52  		 Med Threshold 26

# %%
plt.bar(dict_total_coms.keys(), sorted(n_res_in_comms, reverse=True), color='0.40')
plt.ylabel('Número de recursos.')
plt.xlabel('Comunidad.')
plt.tick_params(labelbottom=False)
#plt.savefig('n_recursos_por_comunidad_amz.pdf')

# %%
lista_tamano_coms = []
for i in dict_total_coms:
    lista_tamano_coms.append(dict_total_coms[i][0].vcount())
    #print(dict_total_coms[i][0].vcount())
len(lista_tamano_coms)

# plt.figure(figsize=(20,15))
plt.bar(dict_total_coms.keys(), sorted(lista_tamano_coms, reverse=True), color='0.40')
plt.ylabel('Número de vértices.')
plt.xlabel('Comunidad.')
plt.tick_params(labelbottom=False)
#plt.savefig('n_vertices_por_comunidad_amz.pdf')

# %%
# plt.figure(figsize=(20,15))
plt.bar(dict_total_coms.keys(), sorted(n_res_in_comms, reverse=True), color='0.40')
plt.ylabel('Número de recursos.')
plt.xlabel('Comunidad.')
x, y = [0, len(n_res_in_comms)-1] , [big_threshold, big_threshold]
plt.plot(x, y, marker = 'o', linestyle='--', color="0.6")
plt.text(len(n_res_in_comms)-5, big_threshold+6, '{} >'.format(big_threshold) , ha='left', va= 'top')
x, y = [0, len(n_res_in_comms)-1] , [med_threshold, med_threshold]
plt.plot(x, y, marker = 'o', linestyle='--', color="0.6")
plt.text(len(n_res_in_comms)-5, med_threshold+6, '{} >'.format(med_threshold) , ha='left', va= 'top')
plt.tick_params(labelbottom=False)
#plt.savefig('n_recursos_por_comunidad_amz-corte.pdf')

# %%
def agregar_tipo_com(grafo, set_users_, tipo):
    for user_ in set_users_:
        vertice = grafo.vs.find(name=user_)
        vertice["tipoCom"] = tipo

# %%
big_comms = [] # Almacenar las comunidades grandes
med_comms = [] # Almacenar las comunidades medianas
sma_comms = [] # Almacenar las comunidades pequeñas
user_network.vs["tipoCom"] = -1


for idx_com, com in enumerate(dict_total_coms.values()):
    if len(com[1]) > big_threshold: # Es comunidad grande
        big_comms.append([idx_com]+com)
        nodos_ = com[0].vs["name"]
        agregar_tipo_com(user_network, nodos_, 0)
    elif len(com[1]) > med_threshold: # Es comunidad mediana
        med_comms.append([idx_com]+com)
        nodos_ = com[0].vs["name"]
        agregar_tipo_com(user_network, nodos_, 1)
    else:
        sma_comms.append([idx_com]+com)
        nodos_ = com[0].vs["name"]
        agregar_tipo_com(user_network, nodos_, 2)

print("# Comunidades:",len(big_comms)+len(med_comms)+len(sma_comms), "==", len(dict_total_coms))
print("Big Comms:", len(big_comms))
print("Med Comms:", len(med_comms))
print("Sma Comms:", len(sma_comms))
# Out:
# # Comunidades: 90 == 90
# Big Comms: 11
# Med Comms: 7
# Sma Comms: 72

# %%
### Density distribution of each community

density_distribution = [] # Store all densities

for comty in sma_comms+med_comms+big_comms: # Loop over all type communities    
    temp_density = comty[1].density() # Graph object [1]
    density_distribution.append(temp_density)

fig, axs = plt.subplots(1, 2, figsize=(14,5))

counts, bins = np.histogram(density_distribution, 20)

# Density distribution
axs[0].set_title('Density distribution')
axs[0].hist(bins[:-1], bins, weights=counts, color="#e60049")
axs[0].set(ylabel='# Communities', xlabel='density')

axs[1].set_title('Density distribution comulative')
axs[1].hist(bins[:-1], bins, weights=counts, color="#e60049", cumulative=True,
            histtype="bar")
axs[1].set(ylabel='# Communities', xlabel='density')

plt.show()

# %%
### Resource accessed distribution by communities
# Recorresr todos los recursos y ver los usuarios que acceden al él. Detectar
# de cual tipo de comunidad atrae más usuarios.

all_types_coms = sma_comms + med_comms + big_comms # All types of communitites

 # Store the number of users in each type of community
dict_user_coms = {} # Example -> {id_res: {sma: 40, med: 12, big: 4}, ...}

for rsrc in bip_network.vs.select(typen=1):
    # Get all users "name" which accessed to the rsrc (resource)
    users_name_accessed = [i["name"] for i in rsrc.neighbors()]

    # Counters
    counter_small = 0
    counter_med = 0
    counter_big = 0
    rsr_impor_sma = rsr_impor_med = rsr_impor_big = 0    
    counter_coms = 0
    counter_coms_type_sma = counter_coms_type_med = counter_coms_type_big = 0
    
    # Get all user in small communities
    for comty in sma_comms:
        users_in_com = comty[1].vs["name"]    
        # Intersection of above lists
        intersec_users = set(users_in_com).intersection(set(users_name_accessed))
        if len(intersec_users) > 0:
            counter_small += len(intersec_users)
            rsr_impor_sma += len(intersec_users) / len(users_in_com)
            counter_coms += 1

    if counter_coms > 0:
        rsr_impor_sma = rsr_impor_sma / counter_coms
        counter_coms_type_sma = counter_coms / len(sma_comms)
    else:
        rsr_impor_sma = 0
        counter_coms_type_sma = 0
    counter_coms = 0

    # Get all user in small communities
    for comty in med_comms:
        users_in_com = comty[1].vs["name"]    
        # Intersection of above lists
        intersec_users = set(users_in_com).intersection(set(users_name_accessed))
        if len(intersec_users) > 0:
            counter_med += len(intersec_users)
            rsr_impor_med += len(intersec_users) / len(users_in_com)
            counter_coms += 1
        
    if counter_coms > 0:
        rsr_impor_med = rsr_impor_med / counter_coms
        counter_coms_type_med = counter_coms / len(med_comms)
    else:
        rsr_impor_med = 0
        counter_coms_type_med = 0
    counter_coms = 0

    for comty in big_comms:
        users_in_com = comty[1].vs["name"]    
        # Intersection of above lists
        intersec_users = set(users_in_com).intersection(set(users_name_accessed))
        if len(intersec_users) > 0:
            counter_big += len(intersec_users)
            rsr_impor_big += len(intersec_users) / len(users_in_com)
            counter_coms += 1

    if counter_coms > 0:
        rsr_impor_big = rsr_impor_big / counter_coms
        counter_coms_type_big = counter_coms / len(big_comms)
    else:
        rsr_impor_big = 0
        counter_coms_type_big = 0
    counter_coms = 0

    
    total_accessed = counter_big + counter_small + counter_med
    total_counter_coms = counter_coms_type_sma + counter_coms_type_med + counter_coms_type_big
    total_rsr_impor = rsr_impor_sma + rsr_impor_med + rsr_impor_big
    # Add all counters
    dict_user_coms[rsrc["name"]] = {"sma": counter_small/total_accessed,
                                     "med": counter_med/total_accessed,
                                     "big":counter_big/total_accessed,
                                     "impComSma": counter_coms_type_sma/total_counter_coms,
                                     "impComMed": counter_coms_type_med/total_counter_coms,
                                     "impComBig": counter_coms_type_big/total_counter_coms,
                                     "impsma": rsr_impor_sma/total_rsr_impor,
                                     "impmed": rsr_impor_med/total_rsr_impor,
                                     "impbig": rsr_impor_big/total_rsr_impor}
    
#dict_user_coms

# %%
a = pd.DataFrame(dict_user_coms)
a = a.T
a["name"] = range(150)
a = a.sort_values("sma", ascending=False)
a
# Out:
#        sma       med       big  impComSma  impComMed  impComBig  impsma  \
# 20294  1.0  0.000000  0.000000        1.0   0.000000   0.000000     1.0
# 39879  1.0  0.000000  0.000000        1.0   0.000000   0.000000     1.0
# 26437  1.0  0.000000  0.000000        1.0   0.000000   0.000000     1.0
# 391    1.0  0.000000  0.000000        1.0   0.000000   0.000000     1.0
# 29304  1.0  0.000000  0.000000        1.0   0.000000   0.000000     1.0
# ...    ...       ...       ...        ...        ...        ...     ...
# 79092  0.0  0.000000  1.000000        0.0   0.000000   1.000000     0.0
# 75078  0.0  0.000000  1.000000        0.0   0.000000   1.000000     0.0
# 17278  0.0  0.421875  0.578125        0.0   0.385965   0.614035     0.0
# 75834  0.0  0.000000  1.000000        0.0   0.000000   1.000000     0.0
# 40069  0.0  0.095238  0.904762        0.0   0.320388   0.679612     0.0
#
#          impmed    impbig  name
# 20294  0.000000  0.000000    74
# 39879  0.000000  0.000000   127
# 26437  0.000000  0.000000   148
# 391    0.000000  0.000000     3
# 29304  0.000000  0.000000     4
# ...         ...       ...   ...
# 79092  0.000000  1.000000     5
# 75078  0.000000  1.000000    19
# 17278  0.769492  0.230508    31
# 75834  0.000000  1.000000     2
# 40069  0.462078  0.537922   123
#
# [150 rows x 10 columns]

# %%
 #plot a Stacked Bar Graph

plt.figure(figsize=(20,30))
a.plot(
    x = "name",
    kind = 'barh',
    stacked = True,
    title = 'Stacked Bar Graph',
    mark_right = True, figsize=(20,30))
plt.show()

# %%
list(bip_network.vs())
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 0, {'name': 9991643999, 'typen': 0, 'test': 9}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 1, {'name': 39262, 'typen': 1, 'test': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 2, {'name': 999167999, 'typen': 0, 'test': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 3, {'name': 17308, 'typen': 1, 'test': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 4, {'name': 9997708999, 'typen': 0, 'test': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>,
, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 928, {'name': 9991279999, 'typen': 0, 'test': None, 'cluster': 55, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 929, {'name': 9995333999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 930, {'name': 9995751999, 'typen': 0, 'test': None, 'cluster': 26, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 931, {'name': 9991574999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 932, {'name': 9991284999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 933, {'name': 9991341999, 'typen': 0, 'test': None, 'cluster': 70, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 934, {'name': 9993893999, 'typen': 0, 'test': None, 'cluster': 34, 'tipoC': 1}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 935, {'name': 9993177999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 936, {'name': 9991030999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 937, {'name': 999777999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 938, {'name': 9995156999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 939, {'name': 9998373999, 'typen': 0, 'test': None, 'cluster': 44, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 940, {'name': 999934999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 941, {'name': 9994963999, 'typen': 0, 'test': None, 'cluster': 26, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 942, {'name': 9991137999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 943, {'name': 9996556999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 944, {'name': 9993842999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 945, {'name': 999931999, 'typen': 0, 'test': None, 'cluster': 35, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 946, {'name': 9991809999, 'typen': 0, 'test': None, 'cluster': 85, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 947, {'name': 38704, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 948, {'name': 9995157999, 'typen': 0, 'test': None, 'cluster': 24, 'tipoC': 1}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 949, {'name': 9991684999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 950, {'name': 9991780999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 951, {'name': 9992061999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 952, {'name': 9997313999, 'typen': 0, 'test': None, 'cluster': 29, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 953, {'name': 9997358999, 'typen': 0, 'test': None, 'cluster': 42, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 954, {'name': 9996539999, 'typen': 0, 'test': None, 'cluster': 56, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 955, {'name': 9991347999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 956, {'name': 9998401999, 'typen': 0, 'test': None, 'cluster': 71, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 957, {'name': 9994213999, 'typen': 0, 'test': None, 'cluster': 64, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 958, {'name': 9995703999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 959, {'name': 9992488999, 'typen': 0, 'test': None, 'cluster': 54, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 960, {'name': 9991797999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 961, {'name': 9992333999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 962, {'name': 9991349999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 963, {'name': 9995843999, 'typen': 0, 'test': None, 'cluster': 49, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 964, {'name': 9997037999, 'typen': 0, 'test': None, 'cluster': 29, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 965, {'name': 9993936999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 966, {'name': 9991351999, 'typen': 0, 'test': None, 'cluster': 32, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 967, {'name': 999245999, 'typen': 0, 'test': None, 'cluster': 54, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 968, {'name': 9992014999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 969, {'name': 9994473999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 970, {'name': 9992520999, 'typen': 0, 'test': None, 'cluster': 38, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 971, {'name': 99969999, 'typen': 0, 'test': None, 'cluster': 17, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 972, {'name': 9993222999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 973, {'name': 9995707999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 974, {'name': 9992877999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 975, {'name': 9994949999, 'typen': 0, 'test': None, 'cluster': 53, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 976, {'name': 9991413999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 977, {'name': 999760999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 978, {'name': 9992162999, 'typen': 0, 'test': None, 'cluster': 50, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 979, {'name': 9997479999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 980, {'name': 999188999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 981, {'name': 999418999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 982, {'name': 999141999, 'typen': 0, 'test': None, 'cluster': 64, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 983, {'name': 9995452999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 984, {'name': 9991175999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 985, {'name': 999967999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 986, {'name': 999180999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 987, {'name': 9994739999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 988, {'name': 9996757999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 989, {'name': 999847999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 990, {'name': 9992867999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 991, {'name': 9996720999, 'typen': 0, 'test': None, 'cluster': 34, 'tipoC': 1}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 992, {'name': 9997828999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 993, {'name': 9992474999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 994, {'name': 9996314999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 995, {'name': 9993947999, 'typen': 0, 'test': None, 'cluster': 75, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 996, {'name': 9996499999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 997, {'name': 9995608999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 998, {'name': 9994032999, 'typen': 0, 'test': None, 'cluster': 39, 'tipoC': 2}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd29063cd50>, 999, {'name': 9995767999, 'typen': 0, 'test': None, 'cluster': 63, 'tipoC': 2}),
#  ...]

# %%
# Export Bip network with clusters id
ig.write(bip_network, "bip_with_data.graphml")

# %%
user_dict[9990999]
# Out:
# [85475, 117961, 118300, 123472, 117905, 117906, 290919, 117908]

# %%
user_attrs
# Out:
# Index(['MGR_ID', 'ROLE_ROLLUP_1', 'ROLE_ROLLUP_2', 'ROLE_DEPTNAME',
#        'ROLE_TITLE', 'ROLE_FAMILY_DESC', 'ROLE_FAMILY', 'ROLE_CODE'],
#       dtype='object')

# %%
copy_bip = bip_network.copy()
test = copy_bip.vs.select(typen=0)

for user_ in test: # Loop over users in bipartite network
    # Find their node in user_network
    #node_user_net = user_network.vs.find(name=user_["name"])
    data_user = user_dict[user_["name"]]
    user_[user_attrs[0]] = data_user[0]
    user_[user_attrs[1]] = data_user[1]
    user_[user_attrs[2]] = data_user[2]
    user_[user_attrs[3]] = data_user[3]
    user_[user_attrs[4]] = data_user[4]
    user_[user_attrs[5]] = data_user[5]
    user_[user_attrs[6]] = data_user[6]
    user_[user_attrs[7]] = data_user[7]
    #user_["cluster"] = node_user_net["cluster"]
    #user_["tipoC"] = node_user_net["tipoCom"]

list(copy_bip.vs())
# Out:
# [igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 0, {'name': 9991643999, 'typen': 0, 'test': 9, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 16527, 'ROLE_ROLLUP_1': 91261, 'ROLE_ROLLUP_2': 118026, 'ROLE_DEPTNAME': 118202, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 1, {'name': 39262, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 2, {'name': 999167999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 139593, 'ROLE_ROLLUP_1': 117902, 'ROLE_ROLLUP_2': 118041, 'ROLE_DEPTNAME': 119781, 'ROLE_TITLE': 130479, 'ROLE_FAMILY_DESC': 179826, 'ROLE_FAMILY': 119784, 'ROLE_CODE': 130481}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 3, {'name': 17308, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 4, {'name': 9997708999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 44024, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 117962, 'ROLE_DEPTNAME': 122224, 'ROLE_TITLE': 120690, 'ROLE_FAMILY_DESC': 122225, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 120692}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 5, {'name': 75834, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 6, {'name': 9997625999, 'typen': 0, 'test': None, 'cluster': 40, 'tipoC': 2, 'MGR_ID': 79911, 'ROLE_ROLLUP_1': 117922, 'ROLE_ROLLUP_2': 117923, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117886, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 7, {'name': 391, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 8, {'name': 9994445999, 'typen': 0, 'test': None, 'cluster': 1, 'tipoC': 1, 'MGR_ID': 25293, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 118317, 'ROLE_TITLE': 121414, 'ROLE_FAMILY_DESC': 130802, 'ROLE_FAMILY': 118704, 'ROLE_CODE': 121416}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 9, {'name': 9996406999, 'typen': 0, 'test': None, 'cluster': 46, 'tipoC': 2, 'MGR_ID': 90018, 'ROLE_ROLLUP_1': 117975, 'ROLE_ROLLUP_2': 117976, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117886, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 10, {'name': 29304, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 11, {'name': 9991751999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 52735, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118052, 'ROLE_DEPTNAME': 120356, 'ROLE_TITLE': 122067, 'ROLE_FAMILY_DESC': 127906, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 122069}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 12, {'name': 79092, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 13, {'name': 9994011999, 'typen': 0, 'test': None, 'cluster': 35, 'tipoC': 2, 'MGR_ID': 18040, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118783, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 240983, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 14, {'name': 7543, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 15, {'name': 9994557999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 8164, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 120685, 'ROLE_TITLE': 118841, 'ROLE_FAMILY_DESC': 166363, 'ROLE_FAMILY': 118643, 'ROLE_CODE': 118843}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 16, {'name': 4675, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 17, {'name': 9992954999, 'typen': 0, 'test': None, 'cluster': 28, 'tipoC': 2, 'MGR_ID': 14861, 'ROLE_ROLLUP_1': 117890, 'ROLE_ROLLUP_2': 117891, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117879, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 18, {'name': 7678, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 19, {'name': 9993139999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 50495, 'ROLE_ROLLUP_1': 117910, 'ROLE_ROLLUP_2': 117911, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 142278, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 20, {'name': 13878, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 21, {'name': 9993133999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 15967, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 124942, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 240983, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 22, {'name': 3853, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 23, {'name': 9991081999, 'typen': 0, 'test': None, 'cluster': 27, 'tipoC': 2, 'MGR_ID': 50281, 'ROLE_ROLLUP_1': 118079, 'ROLE_ROLLUP_2': 118080, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 118177, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 24, {'name': 14354, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 25, {'name': 9992828999, 'typen': 0, 'test': None, 'cluster': 1, 'tipoC': 1, 'MGR_ID': 4928, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 123007, 'ROLE_TITLE': 118826, 'ROLE_FAMILY_DESC': 257115, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118828}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 26, {'name': 45300, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 27, {'name': 99920999, 'typen': 0, 'test': None, 'cluster': 1, 'tipoC': 1, 'MGR_ID': 5220, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118458, 'ROLE_TITLE': 120006, 'ROLE_FAMILY_DESC': 303717, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120008}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 28, {'name': 79121, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 29, {'name': 9993281999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 4413, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118833, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 290878, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 30, {'name': 9991213999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 4175, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118292, 'ROLE_TITLE': 119433, 'ROLE_FAMILY_DESC': 133686, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 119435}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 31, {'name': 971, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 32, {'name': 9991397999, 'typen': 0, 'test': None, 'cluster': 1, 'tipoC': 1, 'MGR_ID': 4757, 'ROLE_ROLLUP_1': 118212, 'ROLE_ROLLUP_2': 118213, 'ROLE_DEPTNAME': 118458, 'ROLE_TITLE': 119849, 'ROLE_FAMILY_DESC': 290535, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 119851}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 33, {'name': 5112, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 34, {'name': 9992113999, 'typen': 0, 'test': None, 'cluster': 42, 'tipoC': 2, 'MGR_ID': 19429, 'ROLE_ROLLUP_1': 117918, 'ROLE_ROLLUP_2': 117919, 'ROLE_DEPTNAME': 117912, 'ROLE_TITLE': 117885, 'ROLE_FAMILY_DESC': 117913, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117888}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 35, {'name': 20292, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 36, {'name': 9995974999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 7524, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 119195, 'ROLE_TITLE': 118636, 'ROLE_FAMILY_DESC': 227378, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 118639}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 37, {'name': 32270, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 38, {'name': 999792999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 15389, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 122870, 'ROLE_TITLE': 118636, 'ROLE_FAMILY_DESC': 310589, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 118639}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 39, {'name': 278393, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 40, {'name': 9995775999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 71189, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 121883, 'ROLE_TITLE': 118278, 'ROLE_FAMILY_DESC': 125206, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118279}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 41, {'name': 75078, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 42, {'name': 9995282999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 193, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118413, 'ROLE_DEPTNAME': 121639, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 118448, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 43, {'name': 9999206999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2, 'MGR_ID': 13971, 'ROLE_ROLLUP_1': 119615, 'ROLE_ROLLUP_2': 119616, 'ROLE_DEPTNAME': 117895, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 281735, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 44, {'name': 33642, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 45, {'name': 9993122999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 4565, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 121961, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 46, {'name': 34861, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 47, {'name': 9997741999, 'typen': 0, 'test': None, 'cluster': 49, 'tipoC': 2, 'MGR_ID': 50322, 'ROLE_ROLLUP_1': 117959, 'ROLE_ROLLUP_2': 117960, 'ROLE_DEPTNAME': 119424, 'ROLE_TITLE': 179731, 'ROLE_FAMILY_DESC': 119617, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117973}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 48, {'name': 37734, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 49, {'name': 9991828999, 'typen': 0, 'test': None, 'cluster': 40, 'tipoC': 2, 'MGR_ID': 46571, 'ROLE_ROLLUP_1': 117922, 'ROLE_ROLLUP_2': 117923, 'ROLE_DEPTNAME': 117920, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 159847, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 50, {'name': 9995477999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 52902, 'ROLE_ROLLUP_1': 118595, 'ROLE_ROLLUP_2': 118596, 'ROLE_DEPTNAME': 81476, 'ROLE_TITLE': 120344, 'ROLE_FAMILY_DESC': 138524, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120346}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 51, {'name': 25993, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 52, {'name': 9993408999, 'typen': 0, 'test': None, 'cluster': 54, 'tipoC': 2, 'MGR_ID': 25618, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 118641, 'ROLE_FAMILY_DESC': 150275, 'ROLE_FAMILY': 118643, 'ROLE_CODE': 118644}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 53, {'name': 34817, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 54, {'name': 9991058999, 'typen': 0, 'test': None, 'cluster': 24, 'tipoC': 1, 'MGR_ID': 57104, 'ROLE_ROLLUP_1': 130684, 'ROLE_ROLLUP_2': 130685, 'ROLE_DEPTNAME': 118378, 'ROLE_TITLE': 121372, 'ROLE_FAMILY_DESC': 300603, 'ROLE_FAMILY': 119184, 'ROLE_CODE': 121374}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 55, {'name': 1020, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 56, {'name': 9994868999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 5030, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 120126, 'ROLE_TITLE': 120497, 'ROLE_FAMILY_DESC': 309858, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120499}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 57, {'name': 31825, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 58, {'name': 9994999, 'typen': 0, 'test': None, 'cluster': 42, 'tipoC': 2, 'MGR_ID': 5905, 'ROLE_ROLLUP_1': 117929, 'ROLE_ROLLUP_2': 117930, 'ROLE_DEPTNAME': 119569, 'ROLE_TITLE': 119323, 'ROLE_FAMILY_DESC': 123932, 'ROLE_FAMILY': 19793, 'ROLE_CODE': 119325}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 59, {'name': 18913, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 60, {'name': 9992857999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 7339, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118360, 'ROLE_TITLE': 124194, 'ROLE_FAMILY_DESC': 130884, 'ROLE_FAMILY': 118363, 'ROLE_CODE': 124196}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 61, {'name': 6977, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 62, {'name': 999749999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 21303, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 119890, 'ROLE_TITLE': 307024, 'ROLE_FAMILY_DESC': 152866, 'ROLE_FAMILY': 118331, 'ROLE_CODE': 118332}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 63, {'name': 999793999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4642, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 120551, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 133936, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 64, {'name': 9991064999, 'typen': 0, 'test': None, 'cluster': 36, 'tipoC': 1, 'MGR_ID': 17227, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118979, 'ROLE_TITLE': 118826, 'ROLE_FAMILY_DESC': 158101, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118828}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 65, {'name': 18418, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 66, {'name': 999215999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 87910, 'ROLE_ROLLUP_1': 91261, 'ROLE_ROLLUP_2': 118026, 'ROLE_DEPTNAME': 119507, 'ROLE_TITLE': 118278, 'ROLE_FAMILY_DESC': 118260, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118279}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 67, {'name': 9998334999, 'typen': 0, 'test': None, 'cluster': 74, 'tipoC': 2, 'MGR_ID': 46634, 'ROLE_ROLLUP_1': 118256, 'ROLE_ROLLUP_2': 118257, 'ROLE_DEPTNAME': 117945, 'ROLE_TITLE': 117946, 'ROLE_FAMILY_DESC': 299126, 'ROLE_FAMILY': 292795, 'ROLE_CODE': 117948}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 68, {'name': 38972, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 69, {'name': 9993027999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 51091, 'ROLE_ROLLUP_1': 117887, 'ROLE_ROLLUP_2': 119256, 'ROLE_DEPTNAME': 124266, 'ROLE_TITLE': 118422, 'ROLE_FAMILY_DESC': 300136, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118425}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 70, {'name': 17278, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 71, {'name': 9993234999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 15902, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118052, 'ROLE_DEPTNAME': 120398, 'ROLE_TITLE': 118834, 'ROLE_FAMILY_DESC': 136989, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118836}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 72, {'name': 33248, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 73, {'name': 9998695999, 'typen': 0, 'test': None, 'cluster': 17, 'tipoC': 2, 'MGR_ID': 15061, 'ROLE_ROLLUP_1': 91261, 'ROLE_ROLLUP_2': 118026, 'ROLE_DEPTNAME': 119507, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 74, {'name': 39883, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 75, {'name': 9992499999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 4729, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 125821, 'ROLE_TITLE': 118054, 'ROLE_FAMILY_DESC': 118443, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 118055}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 76, {'name': 999537999, 'typen': 0, 'test': None, 'cluster': 48, 'tipoC': 2, 'MGR_ID': 50015, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 119598, 'ROLE_TITLE': 118422, 'ROLE_FAMILY_DESC': 300136, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118425}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 77, {'name': 9991013999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 5253, 'ROLE_ROLLUP_1': 118887, 'ROLE_ROLLUP_2': 118888, 'ROLE_DEPTNAME': 120126, 'ROLE_TITLE': 118980, 'ROLE_FAMILY_DESC': 188371, 'ROLE_FAMILY': 118295, 'ROLE_CODE': 118982}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 78, {'name': 9993290999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 124925, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 122273, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 147114, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 79, {'name': 15720, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 80, {'name': 9994333999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 3085, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 125821, 'ROLE_TITLE': 119849, 'ROLE_FAMILY_DESC': 154949, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 119851}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 81, {'name': 42085, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 82, {'name': 9994554999, 'typen': 0, 'test': None, 'cluster': 58, 'tipoC': 2, 'MGR_ID': 26320, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118391, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 83, {'name': 44812, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 84, {'name': 9992358999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 9597, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 120317, 'ROLE_TITLE': 129561, 'ROLE_FAMILY_DESC': 134531, 'ROLE_FAMILY': 3130, 'ROLE_CODE': 129563}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 85, {'name': 3130, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 86, {'name': 9994012999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 7510, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 118684, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 118785, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 87, {'name': 23921, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 88, {'name': 9993995999, 'typen': 0, 'test': None, 'cluster': 52, 'tipoC': 2, 'MGR_ID': 28275, 'ROLE_ROLLUP_1': 118315, 'ROLE_ROLLUP_2': 118463, 'ROLE_DEPTNAME': 123089, 'ROLE_TITLE': 118278, 'ROLE_FAMILY_DESC': 128796, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118279}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 89, {'name': 9993562999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 27214, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 118733, 'ROLE_TITLE': 118685, 'ROLE_FAMILY_DESC': 279443, 'ROLE_FAMILY': 308574, 'ROLE_CODE': 118687}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 90, {'name': 35376, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 91, {'name': 999264999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4933, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118458, 'ROLE_TITLE': 120006, 'ROLE_FAMILY_DESC': 311622, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120008}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 92, {'name': 9992958999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 6047, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118413, 'ROLE_DEPTNAME': 120370, 'ROLE_TITLE': 118777, 'ROLE_FAMILY_DESC': 279443, 'ROLE_FAMILY': 308574, 'ROLE_CODE': 118779}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 93, {'name': 9992736999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 17319, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 117962, 'ROLE_DEPTNAME': 118791, 'ROLE_TITLE': 121469, 'ROLE_FAMILY_DESC': 310997, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 121471}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 94, {'name': 17226, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 95, {'name': 9991402999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 5002, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 119598, 'ROLE_TITLE': 120344, 'ROLE_FAMILY_DESC': 310997, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120346}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 96, {'name': 9995466999, 'typen': 0, 'test': None, 'cluster': 27, 'tipoC': 2, 'MGR_ID': 22871, 'ROLE_ROLLUP_1': 118219, 'ROLE_ROLLUP_2': 118220, 'ROLE_DEPTNAME': 118008, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117897, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 97, {'name': 14570, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 98, {'name': 9991723999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2, 'MGR_ID': 65834, 'ROLE_ROLLUP_1': 117983, 'ROLE_ROLLUP_2': 117984, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 292195, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 99, {'name': 999444999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 3032, 'ROLE_ROLLUP_1': 118212, 'ROLE_ROLLUP_2': 118213, 'ROLE_DEPTNAME': 123201, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 125206, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 100, {'name': 9996613999, 'typen': 0, 'test': None, 'cluster': 40, 'tipoC': 2, 'MGR_ID': 87226, 'ROLE_ROLLUP_1': 118106, 'ROLE_ROLLUP_2': 118107, 'ROLE_DEPTNAME': 117912, 'ROLE_TITLE': 117885, 'ROLE_FAMILY_DESC': 117913, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117888}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 101, {'name': 9992708999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2, 'MGR_ID': 55627, 'ROLE_ROLLUP_1': 117980, 'ROLE_ROLLUP_2': 118076, 'ROLE_DEPTNAME': 131868, 'ROLE_TITLE': 128093, 'ROLE_FAMILY_DESC': 163160, 'ROLE_FAMILY': 119184, 'ROLE_CODE': 128095}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 102, {'name': 1969, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 103, {'name': 9998047999, 'typen': 0, 'test': None, 'cluster': 34, 'tipoC': 1, 'MGR_ID': 60792, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 121694, 'ROLE_TITLE': 118536, 'ROLE_FAMILY_DESC': 147608, 'ROLE_FAMILY': 308574, 'ROLE_CODE': 118539}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 104, {'name': 999404999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 3281, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 119238, 'ROLE_TITLE': 122849, 'ROLE_FAMILY_DESC': 120324, 'ROLE_FAMILY': 119095, 'ROLE_CODE': 122850}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 105, {'name': 999412999, 'typen': 0, 'test': None, 'cluster': 29, 'tipoC': 2, 'MGR_ID': 7398, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 119924, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 106, {'name': 23096, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 107, {'name': 9994518999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 4864, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 123055, 'ROLE_TITLE': 120344, 'ROLE_FAMILY_DESC': 310997, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120346}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 108, {'name': 20364, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 109, {'name': 9993737999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 17261, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118833, 'ROLE_TITLE': 118054, 'ROLE_FAMILY_DESC': 120514, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 118055}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 110, {'name': 9997043999, 'typen': 0, 'test': None, 'cluster': 67, 'tipoC': 2, 'MGR_ID': 40922, 'ROLE_ROLLUP_1': 118315, 'ROLE_ROLLUP_2': 118463, 'ROLE_DEPTNAME': 118464, 'ROLE_TITLE': 119172, 'ROLE_FAMILY_DESC': 140159, 'ROLE_FAMILY': 118467, 'ROLE_CODE': 119174}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 111, {'name': 41758, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 112, {'name': 9991083999, 'typen': 0, 'test': None, 'cluster': 34, 'tipoC': 1, 'MGR_ID': 7547, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118933, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 113, {'name': 34924, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 114, {'name': 9991998999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 4993, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118979, 'ROLE_TITLE': 118826, 'ROLE_FAMILY_DESC': 134537, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118828}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 115, {'name': 42093, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 116, {'name': 9993317999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 255037, 'ROLE_ROLLUP_1': 118315, 'ROLE_ROLLUP_2': 118316, 'ROLE_DEPTNAME': 123656, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 208095, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 117, {'name': 999703999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 215806, 'ROLE_ROLLUP_1': 118315, 'ROLE_ROLLUP_2': 118316, 'ROLE_DEPTNAME': 123656, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 242891, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 118, {'name': 28149, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 119, {'name': 9993130999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 1541, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 123173, 'ROLE_TITLE': 119093, 'ROLE_FAMILY_DESC': 120324, 'ROLE_FAMILY': 119095, 'ROLE_CODE': 119096}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 120, {'name': 9992667999, 'typen': 0, 'test': None, 'cluster': 60, 'tipoC': 2, 'MGR_ID': 2199, 'ROLE_ROLLUP_1': 4292, 'ROLE_ROLLUP_2': 126095, 'ROLE_DEPTNAME': 118378, 'ROLE_TITLE': 179731, 'ROLE_FAMILY_DESC': 179731, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117973}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 121, {'name': 25098, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 122, {'name': 999413999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4567, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118514, 'ROLE_TITLE': 118318, 'ROLE_FAMILY_DESC': 168365, 'ROLE_FAMILY': 118205, 'ROLE_CODE': 118319}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 123, {'name': 9994509999, 'typen': 0, 'test': None, 'cluster': 71, 'tipoC': 2, 'MGR_ID': 7684, 'ROLE_ROLLUP_1': 118573, 'ROLE_ROLLUP_2': 118574, 'ROLE_DEPTNAME': 118623, 'ROLE_TITLE': 126684, 'ROLE_FAMILY_DESC': 127423, 'ROLE_FAMILY': 292795, 'ROLE_CODE': 126685}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 124, {'name': 39264, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 125, {'name': 9991814999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 13812, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 120690, 'ROLE_FAMILY_DESC': 120691, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 120692}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 126, {'name': 9991288999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 49521, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 123055, 'ROLE_TITLE': 120006, 'ROLE_FAMILY_DESC': 150350, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120008}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 127, {'name': 999328999, 'typen': 0, 'test': None, 'cluster': 35, 'tipoC': 2, 'MGR_ID': 718, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 119181, 'ROLE_TITLE': 118259, 'ROLE_FAMILY_DESC': 126363, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118261}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 128, {'name': 9996354999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 27898, 'ROLE_ROLLUP_1': 118106, 'ROLE_ROLLUP_2': 118107, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 121445, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 129, {'name': 9991762999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4533, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118700, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 130, {'name': 9995982999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 34612, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 131, {'name': 9994700999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 8150, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 119954, 'ROLE_TITLE': 118318, 'ROLE_FAMILY_DESC': 168365, 'ROLE_FAMILY': 118205, 'ROLE_CODE': 118319}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 132, {'name': 9997692999, 'typen': 0, 'test': None, 'cluster': 16, 'tipoC': 2, 'MGR_ID': 70168, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118052, 'ROLE_DEPTNAME': 121949, 'ROLE_TITLE': 118636, 'ROLE_FAMILY_DESC': 238714, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 118639}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 133, {'name': 74754, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 134, {'name': 9994056999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 49566, 'ROLE_ROLLUP_1': 118595, 'ROLE_ROLLUP_2': 118596, 'ROLE_DEPTNAME': 119993, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 135, {'name': 23964, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 136, {'name': 9993273999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 49655, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 122550, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 137, {'name': 39333, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 138, {'name': 999647999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 17835, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 118403, 'ROLE_TITLE': 128230, 'ROLE_FAMILY_DESC': 302830, 'ROLE_FAMILY': 4673, 'ROLE_CODE': 128231}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 139, {'name': 9999085999, 'typen': 0, 'test': None, 'cluster': 25, 'tipoC': 0, 'MGR_ID': 4952, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118292, 'ROLE_TITLE': 119433, 'ROLE_FAMILY_DESC': 133686, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 119435}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 140, {'name': 9993288999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 4642, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 120551, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 141, {'name': 9994127999, 'typen': 0, 'test': None, 'cluster': 53, 'tipoC': 2, 'MGR_ID': 34608, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 118785, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 142, {'name': 9992291999, 'typen': 0, 'test': None, 'cluster': 47, 'tipoC': 2, 'MGR_ID': 1954, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 117962, 'ROLE_DEPTNAME': 118501, 'ROLE_TITLE': 120702, 'ROLE_FAMILY_DESC': 308462, 'ROLE_FAMILY': 118504, 'ROLE_CODE': 120704}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 143, {'name': 37651, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 144, {'name': 9991056999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4026, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118301, 'ROLE_TITLE': 120497, 'ROLE_FAMILY_DESC': 149226, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120499}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 145, {'name': 31441, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 146, {'name': 9993982999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2, 'MGR_ID': 49798, 'ROLE_ROLLUP_1': 117975, 'ROLE_ROLLUP_2': 117976, 'ROLE_DEPTNAME': 118246, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 174308, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 147, {'name': 20349, 'typen': 1, 'test': None, 'cluster': None, 'tipoC': None, 'MGR_ID': None, 'ROLE_ROLLUP_1': None, 'ROLE_ROLLUP_2': None, 'ROLE_DEPTNAME': None, 'ROLE_TITLE': None, 'ROLE_FAMILY_DESC': None, 'ROLE_FAMILY': None, 'ROLE_CODE': None}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 148, {'name': 9999543999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 71385, 'ROLE_ROLLUP_1': 118315, 'ROLE_ROLLUP_2': 118463, 'ROLE_DEPTNAME': 118522, 'ROLE_TITLE': 118259, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118261}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 149, {'name': 9995717999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 71192, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 118522, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 147114, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 150, {'name': 999192999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 4341, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118957, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
# ...
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 951, {'name': 9992061999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2, 'MGR_ID': 13165, 'ROLE_ROLLUP_1': 117890, 'ROLE_ROLLUP_2': 118102, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117879, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 952, {'name': 9997313999, 'typen': 0, 'test': None, 'cluster': 29, 'tipoC': 2, 'MGR_ID': 55064, 'ROLE_ROLLUP_1': 126918, 'ROLE_ROLLUP_2': 126919, 'ROLE_DEPTNAME': 118042, 'ROLE_TITLE': 118043, 'ROLE_FAMILY_DESC': 118043, 'ROLE_FAMILY': 270488, 'ROLE_CODE': 118046}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 953, {'name': 9997358999, 'typen': 0, 'test': None, 'cluster': 42, 'tipoC': 2, 'MGR_ID': 19858, 'ROLE_ROLLUP_1': 117929, 'ROLE_ROLLUP_2': 117940, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 117885, 'ROLE_FAMILY_DESC': 117913, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117888}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 954, {'name': 9996539999, 'typen': 0, 'test': None, 'cluster': 56, 'tipoC': 2, 'MGR_ID': 8243, 'ROLE_ROLLUP_1': 117887, 'ROLE_ROLLUP_2': 118178, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 955, {'name': 9991347999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 8699, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118660, 'ROLE_TITLE': 118924, 'ROLE_FAMILY_DESC': 166636, 'ROLE_FAMILY': 118667, 'ROLE_CODE': 118926}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 956, {'name': 9998401999, 'typen': 0, 'test': None, 'cluster': 71, 'tipoC': 2, 'MGR_ID': 46661, 'ROLE_ROLLUP_1': 118256, 'ROLE_ROLLUP_2': 118257, 'ROLE_DEPTNAME': 117945, 'ROLE_TITLE': 118274, 'ROLE_FAMILY_DESC': 118806, 'ROLE_FAMILY': 292795, 'ROLE_CODE': 118276}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 957, {'name': 9994213999, 'typen': 0, 'test': None, 'cluster': 64, 'tipoC': 2, 'MGR_ID': 6833, 'ROLE_ROLLUP_1': 119596, 'ROLE_ROLLUP_2': 119597, 'ROLE_DEPTNAME': 6725, 'ROLE_TITLE': 118368, 'ROLE_FAMILY_DESC': 199235, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 118486}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 958, {'name': 9995703999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 28890, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118529, 'ROLE_TITLE': 118536, 'ROLE_FAMILY_DESC': 137335, 'ROLE_FAMILY': 308574, 'ROLE_CODE': 118539}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 959, {'name': 9992488999, 'typen': 0, 'test': None, 'cluster': 54, 'tipoC': 2, 'MGR_ID': 7610, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 120383, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 960, {'name': 9991797999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 4659, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 120663, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 961, {'name': 9992333999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2, 'MGR_ID': 55636, 'ROLE_ROLLUP_1': 117916, 'ROLE_ROLLUP_2': 118150, 'ROLE_DEPTNAME': 131868, 'ROLE_TITLE': 128093, 'ROLE_FAMILY_DESC': 139264, 'ROLE_FAMILY': 119184, 'ROLE_CODE': 128095}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 962, {'name': 9991349999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 49802, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 118514, 'ROLE_TITLE': 307024, 'ROLE_FAMILY_DESC': 294485, 'ROLE_FAMILY': 118331, 'ROLE_CODE': 118332}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 963, {'name': 9995843999, 'typen': 0, 'test': None, 'cluster': 49, 'tipoC': 2, 'MGR_ID': 12240, 'ROLE_ROLLUP_1': 118090, 'ROLE_ROLLUP_2': 118091, 'ROLE_DEPTNAME': 119424, 'ROLE_TITLE': 179731, 'ROLE_FAMILY_DESC': 133533, 'ROLE_FAMILY': 117887, 'ROLE_CODE': 117973}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 964, {'name': 9997037999, 'typen': 0, 'test': None, 'cluster': 29, 'tipoC': 2, 'MGR_ID': 18080, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 119256, 'ROLE_DEPTNAME': 119257, 'ROLE_TITLE': 117946, 'ROLE_FAMILY_DESC': 119235, 'ROLE_FAMILY': 292795, 'ROLE_CODE': 117948}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 965, {'name': 9993936999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 49850, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118413, 'ROLE_DEPTNAME': 122007, 'ROLE_TITLE': 118259, 'ROLE_FAMILY_DESC': 210052, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118261}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 966, {'name': 9991351999, 'typen': 0, 'test': None, 'cluster': 32, 'tipoC': 2, 'MGR_ID': 51165, 'ROLE_ROLLUP_1': 117983, 'ROLE_ROLLUP_2': 117984, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 118568, 'ROLE_FAMILY_DESC': 292195, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 118570}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 967, {'name': 999245999, 'typen': 0, 'test': None, 'cluster': 54, 'tipoC': 2, 'MGR_ID': 25618, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 118523, 'ROLE_FAMILY_DESC': 310608, 'ROLE_FAMILY': 118331, 'ROLE_CODE': 118525}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 968, {'name': 9992014999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 55195, 'ROLE_ROLLUP_1': 126918, 'ROLE_ROLLUP_2': 126919, 'ROLE_DEPTNAME': 118042, 'ROLE_TITLE': 118043, 'ROLE_FAMILY_DESC': 118043, 'ROLE_FAMILY': 270488, 'ROLE_CODE': 118046}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 969, {'name': 9994473999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 137983, 'ROLE_ROLLUP_1': 118163, 'ROLE_ROLLUP_2': 119075, 'ROLE_DEPTNAME': 119076, 'ROLE_TITLE': 120789, 'ROLE_FAMILY_DESC': 126546, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 120791}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 970, {'name': 9992520999, 'typen': 0, 'test': None, 'cluster': 38, 'tipoC': 2, 'MGR_ID': 5127, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 118597, 'ROLE_TITLE': 118834, 'ROLE_FAMILY_DESC': 146010, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118836}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 971, {'name': 99969999, 'typen': 0, 'test': None, 'cluster': 17, 'tipoC': 2, 'MGR_ID': 55956, 'ROLE_ROLLUP_1': 118555, 'ROLE_ROLLUP_2': 118178, 'ROLE_DEPTNAME': 119262, 'ROLE_TITLE': 117946, 'ROLE_FAMILY_DESC': 119727, 'ROLE_FAMILY': 292795, 'ROLE_CODE': 117948}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 972, {'name': 9993222999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 53027, 'ROLE_ROLLUP_1': 118602, 'ROLE_ROLLUP_2': 118603, 'ROLE_DEPTNAME': 117920, 'ROLE_TITLE': 119192, 'ROLE_FAMILY_DESC': 128322, 'ROLE_FAMILY': 119184, 'ROLE_CODE': 119194}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 973, {'name': 9995707999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 34611, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 118784, 'ROLE_FAMILY_DESC': 147114, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118786}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 974, {'name': 9992877999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 4715, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 125872, 'ROLE_TITLE': 118422, 'ROLE_FAMILY_DESC': 249904, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118425}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 975, {'name': 9994949999, 'typen': 0, 'test': None, 'cluster': 53, 'tipoC': 2, 'MGR_ID': 16850, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118225, 'ROLE_DEPTNAME': 122298, 'ROLE_TITLE': 119093, 'ROLE_FAMILY_DESC': 128819, 'ROLE_FAMILY': 119095, 'ROLE_CODE': 119096}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 976, {'name': 9991413999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 3471, 'ROLE_ROLLUP_1': 118169, 'ROLE_ROLLUP_2': 118170, 'ROLE_DEPTNAME': 118042, 'ROLE_TITLE': 118043, 'ROLE_FAMILY_DESC': 129174, 'ROLE_FAMILY': 270488, 'ROLE_CODE': 118046}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 977, {'name': 999760999, 'typen': 0, 'test': None, 'cluster': 59, 'tipoC': 2, 'MGR_ID': 1080, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 118378, 'ROLE_TITLE': 118451, 'ROLE_FAMILY_DESC': 151171, 'ROLE_FAMILY': 118453, 'ROLE_CODE': 118454}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 978, {'name': 9992162999, 'typen': 0, 'test': None, 'cluster': 50, 'tipoC': 2, 'MGR_ID': 1945, 'ROLE_ROLLUP_1': 118256, 'ROLE_ROLLUP_2': 118257, 'ROLE_DEPTNAME': 118450, 'ROLE_TITLE': 128093, 'ROLE_FAMILY_DESC': 219357, 'ROLE_FAMILY': 119184, 'ROLE_CODE': 128095}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 979, {'name': 9997479999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 2373, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 117962, 'ROLE_DEPTNAME': 118501, 'ROLE_TITLE': 118685, 'ROLE_FAMILY_DESC': 257529, 'ROLE_FAMILY': 308574, 'ROLE_CODE': 118687}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 980, {'name': 999188999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 20560, 'ROLE_ROLLUP_1': 117876, 'ROLE_ROLLUP_2': 117877, 'ROLE_DEPTNAME': 117878, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117879, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 981, {'name': 999418999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 5002, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 119598, 'ROLE_TITLE': 118422, 'ROLE_FAMILY_DESC': 300136, 'ROLE_FAMILY': 118424, 'ROLE_CODE': 118425}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 982, {'name': 999141999, 'typen': 0, 'test': None, 'cluster': 64, 'tipoC': 2, 'MGR_ID': 2290, 'ROLE_ROLLUP_1': 117902, 'ROLE_ROLLUP_2': 117903, 'ROLE_DEPTNAME': 118403, 'ROLE_TITLE': 128422, 'ROLE_FAMILY_DESC': 122352, 'ROLE_FAMILY': 118453, 'ROLE_CODE': 128424}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 983, {'name': 9995452999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 5730, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 125872, 'ROLE_TITLE': 124305, 'ROLE_FAMILY_DESC': 120579, 'ROLE_FAMILY': 118762, 'ROLE_CODE': 124307}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 984, {'name': 9991175999, 'typen': 0, 'test': None, 'cluster': 20, 'tipoC': 0, 'MGR_ID': 5143, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118343, 'ROLE_DEPTNAME': 123125, 'ROLE_TITLE': 119849, 'ROLE_FAMILY_DESC': 244844, 'ROLE_FAMILY': 118638, 'ROLE_CODE': 119851}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 985, {'name': 999967999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 16973, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 124942, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 986, {'name': 999180999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 50997, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118052, 'ROLE_DEPTNAME': 120539, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 118448, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 987, {'name': 9994739999, 'typen': 0, 'test': None, 'cluster': 30, 'tipoC': 2, 'MGR_ID': 15436, 'ROLE_ROLLUP_1': 118216, 'ROLE_ROLLUP_2': 118217, 'ROLE_DEPTNAME': 117941, 'ROLE_TITLE': 117879, 'ROLE_FAMILY_DESC': 117886, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 117880}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 988, {'name': 9996757999, 'typen': 0, 'test': None, 'cluster': 23, 'tipoC': 0, 'MGR_ID': 8243, 'ROLE_ROLLUP_1': 118555, 'ROLE_ROLLUP_2': 118178, 'ROLE_DEPTNAME': 118320, 'ROLE_TITLE': 118451, 'ROLE_FAMILY_DESC': 130134, 'ROLE_FAMILY': 118453, 'ROLE_CODE': 118454}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 989, {'name': 999847999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 52140, 'ROLE_ROLLUP_1': 118887, 'ROLE_ROLLUP_2': 118888, 'ROLE_DEPTNAME': 124656, 'ROLE_TITLE': 118980, 'ROLE_FAMILY_DESC': 236007, 'ROLE_FAMILY': 118295, 'ROLE_CODE': 118982}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 990, {'name': 9992867999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 16928, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 120317, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 991, {'name': 9996720999, 'typen': 0, 'test': None, 'cluster': 34, 'tipoC': 1, 'MGR_ID': 4713, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118052, 'ROLE_DEPTNAME': 120398, 'ROLE_TITLE': 118459, 'ROLE_FAMILY_DESC': 299565, 'ROLE_FAMILY': 249618, 'ROLE_CODE': 118461}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 992, {'name': 9997828999, 'typen': 0, 'test': None, 'cluster': 0, 'tipoC': 0, 'MGR_ID': 23136, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118386, 'ROLE_DEPTNAME': 121961, 'ROLE_TITLE': 117905, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 117908}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 993, {'name': 9992474999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 1065, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 120559, 'ROLE_TITLE': 118641, 'ROLE_FAMILY_DESC': 132791, 'ROLE_FAMILY': 118643, 'ROLE_CODE': 118644}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 994, {'name': 9996314999, 'typen': 0, 'test': None, 'cluster': 80, 'tipoC': 0, 'MGR_ID': 5730, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118446, 'ROLE_DEPTNAME': 118684, 'ROLE_TITLE': 124305, 'ROLE_FAMILY_DESC': 120579, 'ROLE_FAMILY': 118762, 'ROLE_CODE': 124307}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 995, {'name': 9993947999, 'typen': 0, 'test': None, 'cluster': 75, 'tipoC': 2, 'MGR_ID': 15510, 'ROLE_ROLLUP_1': 118169, 'ROLE_ROLLUP_2': 118170, 'ROLE_DEPTNAME': 125857, 'ROLE_TITLE': 247659, 'ROLE_FAMILY_DESC': 147206, 'ROLE_FAMILY': 19721, 'ROLE_CODE': 247660}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 996, {'name': 9996499999, 'typen': 0, 'test': None, 'cluster': 18, 'tipoC': 0, 'MGR_ID': 3395, 'ROLE_ROLLUP_1': 118573, 'ROLE_ROLLUP_2': 118574, 'ROLE_DEPTNAME': 118042, 'ROLE_TITLE': 118043, 'ROLE_FAMILY_DESC': 118043, 'ROLE_FAMILY': 270488, 'ROLE_CODE': 118046}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 997, {'name': 9995608999, 'typen': 0, 'test': None, 'cluster': 19, 'tipoC': 0, 'MGR_ID': 20578, 'ROLE_ROLLUP_1': 120864, 'ROLE_ROLLUP_2': 121013, 'ROLE_DEPTNAME': 121014, 'ROLE_TITLE': 121015, 'ROLE_FAMILY_DESC': 140512, 'ROLE_FAMILY': 119006, 'ROLE_CODE': 121017}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 998, {'name': 9994032999, 'typen': 0, 'test': None, 'cluster': 39, 'tipoC': 2, 'MGR_ID': 771, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118300, 'ROLE_DEPTNAME': 120722, 'ROLE_TITLE': 118321, 'ROLE_FAMILY_DESC': 117906, 'ROLE_FAMILY': 290919, 'ROLE_CODE': 118322}),
#  igraph.Vertex(<igraph.Graph object at 0x7fd2855b1450>, 999, {'name': 9995767999, 'typen': 0, 'test': None, 'cluster': 63, 'tipoC': 2, 'MGR_ID': 27211, 'ROLE_ROLLUP_1': 117961, 'ROLE_ROLLUP_2': 118327, 'ROLE_DEPTNAME': 123757, 'ROLE_TITLE': 118530, 'ROLE_FAMILY_DESC': 278014, 'ROLE_FAMILY': 118131, 'ROLE_CODE': 118532}),
#  ...]

# %%
# Export Bip network with clusters id
ig.write(copy_bip, "bip_with_attrs.graphml")
